# %%
import os
import csv
import ast
import time
import json
import nltk
import spacy
import openai
import random
import requests
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import date
from bertopic import BERTopic
from nltk.tokenize import WhitespaceTokenizer
# nltk.download('stopwords')
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.cluster import AgglomerativeClustering
from sentence_transformers import SentenceTransformer, util
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\kshit\anaconda3\envs\tf\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\kshit\anaconda3\envs\tf\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\kshit\anaconda3\envs\tf\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # jsonl -> dataframe

# %%
with open('all_dec21v2.jsonl', 'r', encoding="utf8") as json_file:
    json_list = list(json_file)

resultList = []
for i in range(len(json_list)):
#     print(i,json_list[i])
    jsonObject = json.loads(json_list[i])
#     print(jsonObject)
    for start, end, category in jsonObject["entities"]:
        result = {}
#         print(jsonObject["id"])
        result["Review ID"] = "P4R" + str(jsonObject["id"])
        result["Review"] = jsonObject["text"]
        result["Date"] = jsonObject["Date"]
        result["Rating"] = int(jsonObject["Rating"].split()[0])
        result["Aspect"] = category.split("_")[0].strip().lower()
        if category.split("_")[1].lower() == "neg":
            result["Type"] = "negative"
            result["Phrase"] = jsonObject["text"][start:end].strip()
        elif category.split("_")[1].lower() == "pos":
            result["Type"] = "positive"
            result["Phrase"] = jsonObject["text"][start:end].strip()
#         print(i,result)
        resultList.append(result)

df = pd.DataFrame.from_dict(resultList, orient='columns')
df.drop(['Date','Rating'],1,inplace=True)
df['new_aspect']=''
# df

# %% [markdown]
# # Mapping in DataFrame

# %%
tags = pd.read_csv('Review Categories - For C2.csv')
tags.drop(['Unnamed: 0','Unnamed: 3'],1,inplace=True)
tags.drop(0,inplace=True)
tags['Not-Preferred Tagging'] = tags['Not-Preferred Tagging'].str.lower()
tags['Not-Preferred Tagging'] = tags['Not-Preferred Tagging'].str.strip()
tags['Preferred Tagging'] = tags['Preferred Tagging'].str.lower()
tags['Preferred Tagging'] = tags['Preferred Tagging'].str.strip()

tags.loc[len(tags.index)+1] = ['skin','skintype']
tags.loc[len(tags.index)+1] = ['skin','skinissue']
tags.loc[len(tags.index)+1] = ['odor','scent']
tags.loc[len(tags.index)+1] = ['application','usage']
tags.loc[len(tags.index)+1] = ['application','change'] 

for i in range(len(df)):
    try:
        df['new_aspect'][i] = list(tags[tags['Not-Preferred Tagging']==df['Aspect'][i]]['Preferred Tagging'])[0]
    except:
        df['new_aspect'][i] = df['Aspect'][i]
        
df.drop(['Aspect'],1,inplace=True)

# %%
plt.figure(figsize=(15, 5))
plt.xticks(rotation = 45)
sns.countplot(x ='new_aspect', data = df,hue='Type')
# Out:
# <AxesSubplot:xlabel='new_aspect', ylabel='count'>

# %%
p = pd.DataFrame(df[df.Type=='positive'].new_aspect.value_counts())
n = pd.DataFrame(df[df.Type=='negative'].new_aspect.value_counts())
p.reset_index(inplace=True)
n.reset_index(inplace=True)

# %%
pd.merge(p,n,on='index')
# Out:
#           index  new_aspect_x  new_aspect_y
# 0          skin           629           146
# 1       texture           267            57
# 2     sentiment           145            41
# 3   application           109            42
# 4   performance            98            27
# 5   demographic            87             8
# 6    motivation            81            12
# 7      purchase            62            25
# 8         price            58            23
# 9       allergy            42           127
# 10    packaging            41            17
# 11         odor            38            32
# 12  ingredients            38            30
# 13        brand            37             6
# 14   competitor            29            55

# %% [markdown]
# # dataframe -> txt file

# %%
s = ''
for id in df.ReviewID.unique():
#     s = s + '##'+id+'\n'
    s = s + '##'
    s = s + list(df[df.ReviewID==id]['Review'])[0]+'\n\n\n'
    r = random.randint(1,10)
    if r%2==0:
        senti = ['positive','negative']
    else:
        senti = ['negative','positive']
        
    for sentiment in senti:
        s = s+sentiment.capitalize()+': \n'
        df1 = df[(df.ReviewID==id)]
        if len(df1[df1.Type==sentiment])==0:
            s = s+'None\n'
        else:
            df1 = df1[(df1.Type==sentiment)]
            for aspect in df1['new_aspect'].unique():
                s = s + aspect.capitalize()+': '
                l = list(df1[df1.new_aspect==aspect]['Phrase'])
                if len(l)==1:
                    s = s + l[0] + '\n'
                else:
                    for phrase in l:
                        s = s + phrase + ', '
                    s = s[:-2]
                    s+='\n'
        if sentiment==senti[0]:
            s = s+'\n'
                
text_file = open("data.txt", "w",encoding="utf8") 
text_file.write(s)
text_file.close()

# %% [markdown]
# # txt file -> jsonl file

# %%
txt = open(r"data.txt","r",encoding="utf8")
s = txt.read()

#string cleaning
while(s[0]!='#'):
    s = s[1:]
    
l = s.split('##')
l.pop(0)

prompt = []
completion = []

for i in range(len(l)):
    prompt.append(l[i].split('\n\n\n')[0])
    completion.append(l[i].split('\n\n\n')[1])
    
data = pd.DataFrame(list(zip(prompt, completion)), columns =['prompt', 'completion'])
data['prompt'] = ' ' + data['prompt'] + '\n\n###\n\n'
data['completion'] = ' ' + data['completion'] + ' END'

# data.to_json("20221221Dv2.jsonl",orient='records',lines=True)

# %%
l = []
for i in range(len(data)):
    l.append(len(data['Prompt'][i].split(' ')))
sum(l)/len(l)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Prompt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-c3f0e0151428> in <module>
#       1 l = []
#       2 for i in range(len(data)):
# ----> 3     l.append(len(data['Prompt'][i].split(' ')))
#       4 sum(l)/len(l)
#
# ~\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Prompt'

# %% [markdown]
# # Layer 2 for docano df

# %%
dfp = df[df.Type=='positive']
dfn = df[df.Type=='negative']
daf = pd.read_csv('P4 first aid beauty.csv')

# %%
#creating a dataframe which contain the count of phrases corresponding to each topic
df1 = pd.DataFrame(dfn.groupby(['new_aspect']).count()['Phrase'])
df1 = df1.reset_index()
df1.columns = ['aspect','phrase_count']   #naming of columns

#creating a dataframe which contain the rating corresponding to each phrase
df2 = pd.merge(dfn,daf.loc[:,['Rating','Review ID']],how='inner',on='Review ID')   #Joining input dataframe and final_df
df2['Rating']=df2['Rating'].str.split(' ',expand=True)[0]   #splitting the rating column to get the numerical values of rating
df2['Rating'] = df2['Rating'].astype(int)   #converting string into integer for computation

df3 = pd.DataFrame(pd.DataFrame(df2.groupby(['new_aspect','Review']).mean()).groupby(['new_aspect']).mean()['Rating'])
df3 = df3.reset_index()
df3.columns = ['aspect','Review_Avg_Rating']
# df3['Review_Avg_Rating'] = round(df3['Review_Avg_Rating'],no_of_decimal_places_in_avg_rating)

#creating a dataframe which contain the average rating corresponding to each topic
df2 = pd.DataFrame(df2.groupby(['new_aspect']).mean()['Rating'])
df2 = df2.reset_index()
df2.columns = ['aspect','Phrase_Avg_Rating']   #naming of columns
# df2['Phrase_Avg_Rating'] = round(df2['Phrase_Avg_Rating'],no_of_decimal_places_in_avg_rating)   #round decimal places in average rating

#Joining of df1 and df2 and creating an output dataframe df3
df4 = pd.merge(df1,df2,how='inner',on='aspect')
df4 = pd.merge(df4,df3,how='inner',on='aspect')
# df4 = df4.sort_values(by=column_to_sort_output,ascending=sort_in_ascending_order)   

aspect_count = {}
for review in dfp.Review.unique():
    for aspect in dfp[dfp.Review==review]['new_aspect'].unique():
        try:
            aspect_count[aspect]+=1
        except:
            aspect_count[aspect]=1
z = pd.DataFrame(aspect_count.items(),columns=['aspect','review_count'])
df4 = pd.merge(df4,z,on='aspect',how='inner')
df4.to_csv('output_negative.csv',index=False)    #uncomment to export output file

# %% [markdown]
# # completion generation

# %%
df = pd.read_csv('P4 first aid beauty.csv')
df = df.loc[1449:2449,['Review Title','Review']].fillna(' ')
df['prompt'] = ' '+df['Review Title']+'\n\n'+df['Review']+'\n\n###\n\n'
df['completion']=''
df.drop([2446,2447],inplace=True)

# %%
x = []
for i in df.index:
    x.append(len(df['completion'][i].split(' '))/len(df['prompt'][i].split(' ')))
sum(x)/len(x)
# Out:
# 0.02821593720644013

# %%
# for i in range(1374,2600):
#     prompt = df1['Review'][i]+'\n\n###\n\n'
#     response = openai.Completion.create(
#       model="davinci:ft-personal-2022-12-21-15-46-23",
#       prompt=prompt,
#       temperature=0.7,
#       max_tokens=256,
#       top_p=1,
#       frequency_penalty=0,
#       presence_penalty=0,
#       stop=["\n END"]
#     )
#     df1['completion'][i] = response['choices'][0]['text']
headers = {
  "Authorization": "Bearer c1f98ef8741f43c9ae897c16",
  "Content-Type": "application/json"
}

# %%
for i in [1616]:
    body = {
      "text": df['prompt'][i],
      "top_p": 1,
      "top_k": 40,
      "temperature": 0.25,
      "repetition_penalty":  1,
      "length": 256,
      "stop_sequences": ["\n END",'*','RECOMM','MEDIUM']
#         ,"bad_words": ["None","###"]
      }

    res = requests.post(
      "https://shared-api.forefront.link/organization/ssnpZIL6SQy1/gpt-j-6b-vanilla/completions/73VyQUhhs6jn",
      json=body,
      headers=headers
    )

    data = res.json()
    df['completion'][i] = data['result'][0]['completion']#.split('END')[0]
    print(i,len(df['prompt'][i].split(' ')),df['prompt'][i])
    print(len(df['completion'][i].split(' ')),df['completion'][i])
# Out:
# 1616 29  Don’t get it
#
# I don’t get the hype.  Are these other reviews fake? was a gift and didn’t like it.  Smells funny.  Feels greasy.  Gross.
#
# ###
#
#
# 1

# %%
df['length'] = '' 
for i in df.index:
    print(i,df['completion'][i])
    df['length'][i] = len(df['completion'][i].split('###'))
    
for i in df[(df.length>=100)]['completion'].index:
#     df.drop([i],inplace=True)
#     print(df['prompt'][i])
    print(i,len(df['prompt'][i].split(' ')),len(df['completion'][i].split(' ')),df['completion'][i])
    
# df.drop([1574],inplace=True)
# df['completion'][1574] = df['completion'][1574].split('###')[1]
# Out:
# 1449
#
# ### Negative:
# None
#
# Positive:
# Skin: serious need of hydration, doesn’t irritate my sensitive skin
# 1450   Positive:
# Skin: dry skin, sensitive skin
#
# Negative:
# Skin: zit, not good combination
# 1451
# ### Positive:
# Motivation: great for my belly bump
#
# Negative:
# Application: never would I ever use this as diaper rash cream
# 1452   Negative:
# Skin: peeling, peeling, peeling
#
# Positive:
# None
# 1453
# ### Negative:
# None
#
# Positive:
# Skin: Combo skin with oily t-zone
# 1454
# ### Positive:
# Skin: dry skin, irritated skin, a rash or sensitive skin
# Texture: doesn’t clog my pores
# Application: put it on before bed
#
# Negative:
# None
# 1455   1. Positive:
#     1. skin used to be really dry
#     2. skin is very sensitive to fragrances
#     3. fragrance-free
#     4. safe for all skin types
#   2. Negative:
#     1. skin is very sensitive to fragrances
#
# ### Negative: None
#
# Positive:
# Skin: skin used to be really dry, skin is very sensitive to fragrances
# 1456   Negative:
# Skin: forehead was better overnight
# Texture: no longer oily
#
# Positive:
# Skin: perfectly smooth
# 1457   Positive: saves my life
#   Negative: nothing
# 1458   Negative:
# Skin: peeling, dry spots
#
# Positive:
# Skin: not flaky, not tight
# 1459   Negative:
# None
#
# Positive:
# Texture: My favorite moisturizer ever!
# 1460
# 1461   Negative:
# None
#
# Positive:
# Skin: Great moisturizer
# Demographic: It did not break the bank
# 1462   Positive:
# Skin: very dry climate, hydrates so well
#
# Negative:
# None
# 1463   Negative:
# None
#
# Positive:
# Texture: absorbs quickly into your skin, doesn't leave any kind of greasy looking sheen
# 1464   Negative:
# None
#
# Positive:
# Skin: sensitive skin
# 1465   Negative:
# None
#
# Positive:
# Skin: Eczema, keeps my skin healthy and moisturized
# 1466   Negative:
# Skin: broke me out more
#
# Positive:
# Texture: made everything else feel so hydrated
# 1467
# ### Positive:
# Skin: absorbs so well
# Sentiment: not scented
#
# Negative:
# None
# 1468
#
# ### Positive:
# Skin: oily skin, normal skin
#
# Negative:
# None
# 1469   Negative:
# None
#
# Positive:
# Skin: eczema, diagnosed with, immediately when I started using
# Purchase: purchased a 12.0 on at Sephora for $15.00 (regularly $42.00)
# 1470   Positive:
# None
#
# Negative:
# Change of formula: some of the fillers (think xanthan gum) are now higher than the beneficial ingredients
#
# Brand: Sephora
# 1471   Positive:
# Skin: super sensitive skin, super dry skin, eczema
# Application: day or night
#
# Negative:
# None
# 1472   Negative:
# None
#
# Positive:
# Texture: doesn't provide long lasting hydration for my face
# 1473   Negative:
# Skin: had REALLY bad dry skin
#
# Positive:
# Skin: completely healed, gone
# 1474   Negative:
# None
#
# Positive:
# Skin: super dry all the time
# 1475   Negative:
# None
#
# Positive:
# Skin: hand eczema
# 1476   Positive:
# Skin: AM use
#
# Negative:
# None
# 1477   Negative:
# Skin: sweat on my face every single time I use this
# Allergy: dimethecone
# 1478
#
# ### Positive:
# Skin: legitimately the best moisturizer
#
# Negative:
# None
# 1479   Negative:
# None
#
# Positive:
# Skin: dry and very sensitive skin, great for my dry and very sensitive skin
# Price: ends up being half the price of my previous drugstore brand moisturizer
# 1480   Negative:
# None
#
# Positive:
# Texture: very buttery
# Performance: heals the parched skin
# 1481
#
# ### Negative:
# None
#
# Positive:
# Texture: feels clean
# Skin: dry skin
# 1482
#
# ### Negative:
# None
#
# Positive:
# Skin: dryness, worked perfectly
# Texture: medium weight/thickness
# Application: babies/children
# 1483   Negative:
# None
#
# Positive:
# Skin: eczema, surpressing some if the itch
# 1484
# Performance: very creamy consistency, applies nicely
# Texture: very heavy
# Allergy: kind of heavy
# Skin: clog my pores causing me to sweat
# 1485   Negative:
# Skin: keeps my skin super moisturizer without clogging my poors!
#
# Positive:
# Allergy: without clogging my poors!
# 1486   Positive:
# Skin: whole family uses this and it's great
# Allergy: skin feels hydrated
#
# Negative:
# None
# 1487
# Rating: 5
#
# Overall:
# Positive: results, great
# Negative: smell
# 1488
#
# ### Negative:
# None
#
# Positive:
# Skin: ecsema, Keritosis Polaris
# Application: apply makeup without any issues
# 1489   Negative:
# None
#
# Positive:
# Skin: aging, drier side, no major skin issues
# Demographic: sensitive skin, cruelty free brands
# 1490
#
# ### Positive:
# Skin: oily skin, doesn’t help with the oiliness
# Texture: soaks in fast
#
# Negative:
# None
# 1491   Positive:
# Skin: use for face mostly, dry patches, elbows, knees, feet
#
# Negative:
# None
# 1492
# Positive:
# Skin: didn’t break me out
#
# Negative:
# Application: peels, smell, too greasy
# 1493
#
# ### Positive:
# Skin: severely burned even with olive italian skin. My knees shoulders and chest mostly.
#
# Negative:
# None
# 1494
#
# ### Positive:
# Skin: consistently oily skin, absorbs fast without leaving my skin greasy
# Texture: tub lasts a long time
#
# Negative:
# None
# 1495
#
# ### Positive:
# Skin: really helped me out with redness on my face
# Allergy: calms down my skin
#
# Negative:
# None
# 1496   Negative:
# Skin: flaky in the winter
#
# Positive:
# Skin: introduced to this cream
# 1497   Negative:
# Texture: not oily
#
# Positive:
# Skin: not oily, moisturizer
# 1498   Positive:
# Skin: very dry and uneven skin textures on my skin
# Texture: cleared everything up within days
# All over: a little goes a long way
# Skin: recommend it for others to use
#
# Negative:
# None
# 1499   Negative:
# None
#
# Positive:
# Texture: very simple for my dry, sensitive skin
# Skin: keeps my skin looking great
# Application: does not apply this in the morning because I do not think it works the best with foundation
# Price: You get a lot of product for the price
# 1500   Negative:
# Skin: sensitive skin, breakout, rash
# Allergy: aveno makes it breakout
#
# Positive:
# Texture: doesnt leave you greasy
# 1501   Positive:
# Skin: keeps my face clean
#
# Negative:
# None
# 1502   Negative:
# None
#
# Positive:
# Skin: keratosis pilaris
# 1503
# 1504   Negative:
# None
#
# Positive:
# Texture: very heavy and moisturizing
# Skin: very gentle on the skin
# Purchase: definitely recommend to purchase
# 1505   Negative:
# None
#
# Positive:
# Skin: combination acne-prone skin, keeps my skin moisturized
# Price: A little goes a long way
# 1506
# 1507   Positive:
# Texture: "whipped"
# Skin: very dry skin, smells amazing
#
# Negative:
# Performance: misjudge how much to use
# 1508   Positive:
# Skin: very bad eczema all over her body
# Application: applied this and it actually soothed her eczema
#
# Negative:
# None
# 1509
# ### Positive:
# Skin: keeps my skin moisturizer ALL DAY!! In the sun, I don’t burn, but sometimes I get dried out.
#
# Negative:
# None
# 1510
# Positive:
# Skin: calm and clear some of the excema
# Texture: end up buying it in multiple sizes
#
# Negative:
# None
# 1511   Negative:
# None
#
# Positive:
# Texture: Love this stuff I cannot live without it
# Skin: super dry skin, and my husband is more oily
# 1512
# Sentiment:
# Skin: super dry skin
# Texture: without being greasy
#
# ### Positive:
# None
#
# Negative:
# None
# 1513   Negative:
# None
#
# Positive:
# Skin: sensitive dry skin w/eczema, topical steroid lotion
# 1514   Negative:
# None
#
# Positive:
# Skin: neck, chest, new problem area
# Texture: so hydrating
# Allergy: None
# 1515   Negative:
# Allergy: baby had a reaction to all of her baby products
#
# Positive:
# Motivation: FAB as I had a tub of Ultra Repair Cream
# 1516
#
# ### Positive:
# Skin: really nice moisturizing and soothing cream
#
# Negative:
# None
# 1517   Positive:
# Skin: rescued my skin, still uses it
# Demographic: nearing the Autumn of 2018
# Packaging: HUGE!
#
# Negative:
# None
# 1518   Negative:
# None
#
# Positive:
# Motivation: miracle product
# Skin: dry hands, dry elbows
# 1519
# ### Negative:
# None
#
# Positive:
# None
# 1520
#
# ### Positive:
# Skin: no complaints, got it in my sephora box
# Texture: very recommend
#
# Negative:
# None
# 1521   Positive:
# Skin: combination skin (oily T-Zone), outer areas can be a bit dry
#
# Negative:
# Allergy: did not moisturize
# 1522   Negative:
# None
#
# Positive:
# Texture: my HG and will forever keep repurchasing
# 1523   Negative:
# Skin: more on the sensitive side
# Allergy: made my face break out in red splotches
#
# Positive:
# None
# 1524   Negative:
# None
#
# Positive:
# Skin: keeps my face clear and hydrated
# Allergy: Not oily
# 1525
#
# ### Negative:
# None
#
# Positive:
# Skin: repair, after just one night with it on my skin is more plump, less dull
# Texture: doesn’t make me oily
# 1526   Negative:
# None
#
# Positive:
# Texture: really lovely! hydrates the skin soooo well!
# 1527   Negative:
# Skin: reverse the dryness on my face
# Price: amazing price point
#
# Positive:
# Skin: plump
# Texture: glides on the face
# 1528   Negative:
# None
#
# Positive:
# Skin: extremely sensitive skin, won't break out my
# Texture: thick, incredibly hydrating moisturizer
# 1529   Positive:
# Skin: messed up my skin with an overly strong grapefruit cleanser
# Texture: does sink into my skin pretty quick
# Price: not too bad but not great
#
# Negative:
# None
# 1530
#
# ### Positive:
# Skin: pretty bad eczema, itchy flare-ups
# Application: carry it everywhere with me
#
# Negative:
# None
# 1531   Negative:
# Skin: really good moisturizer its not god send
# Allergy: never breaks me out
#
# Positive:
# Application: really good moisturizer
# 1532   Positive:
# Skin: redness on my cheeks, dry skin areas
#
# Negative:
# None
# 1533
#
# ### Positive:
# Skin: really sensitive skin, also have psoriasis
# Brand: first brand I’ve tried that actually helped my skin
# Skin: saw a change in my skin within hours
#
# Negative:
# None
# 1534
#
# ### Positive:
# Skin: really dry up to the point where it was starting to peel
#
# Negative:
# None
# 1535   Positive:
# Skin: extra moisture, does not break me out
#
# Negative:
# Allergy: oily skin
# 1536   Positive:
# Skin: good for my skin
#
# Negative:
# None
# 1537   Negative:
# None
#
# Positive:
# Texture: super good on my skin, my makeup would crack
# 1538
# 1539   Negative:
# None
#
# Positive:
# Skin: medium weight thickness hydrates face
# 1540
# Sentiment: very first time I ever saw this was on GMA deals and steals
# ### Positive:
# Skin: my skin just needs a little moisture
# Texture: it’s just as amazing in the winter when I need a lot more of it
# Application: never leaves my skin feeling greasy
# ### Negative:
# None
# 1541   Negative:
# None
#
# Positive:
# Skin: deeply nourishes without feeling heavy, especially in the winter
# 1542   Negative:
# None
#
# Positive:
# Texture: really helped repair my skin
# Skin: bring it back to life despite the dryness of the formula
# 1543   Positive:
# Skin: exfoliating products, dry skin, all over my body
# Texture: scaly dry patch
#
# Negative:
# None
# 1544
#
#
#
#
# ### Positive:
# Skin: the best lotion ever
#
# Negative:
# None
# 1545   Negative:
# Performance: claims to be fragrance-free, but it's not
# Odor: terrible strong smell
#
# Positive:
# Application: Great product
# 1546   Negative:
# Skin: incredibly dry, itchy, sensitive skin, accutane
#
# Positive:
# None
# 1547   Positive:
# Skin: very little oil production in my tzone area
# Texture: sinks into my skin
#
# Negative:
# None
# 1548   Negative:
# None
#
# Positive:
# Skin: combination skin, lean more towards the oily side
# Texture: wake up with soft and hydrated skin
# 1549   Negative:
# Skin: extremely dry, flaky skin around my cheeks
#
# Positive:
# Motivation: needed to find a moisturizer that would actually keep my skin hydrated
# Texture: cream all over my face in the morning
# 1550
# Positive:
# Skin: does not irritate my “sensitive when it wants to be” skin
#
# Negative:
# None
# 1551   Skin: winter season
#   Motivation: my face
#   End result: Saved my face
#
# ### Positive:
# Skin: winter season
# Motivation: my face
#
# Negative:
# None
# 1552   Positive:
# Skin: eczema, s, itchiness, back of my knees
#
# Negative:
# None
# 1553
# Positive:
# Skin: super sensitive and dry skin, dry patches
# 1554   Positive:
# Skin: soaks in immediately, makes my skin feel so soft
# Texture: feels light but very hydrating
# Application: cooling feel when first applied
#
# Negative:
# None
# 1555   Negative:
# None
#
# Positive:
# Skin: burn, sun burn, rough patch on body
# 1556   Negative:
# None
#
# Positive:
# Skin: hydrates, psoriasis, keeps my skin hydrated
# Texture: keeps my skin hydrated
# Allergy: None
# 1557
# Performance: really hydrates your skin!
# Texture: really creamy but absorbs fast
# 1558
#
# ### Negative:
# None
#
# Positive:
# Skin: moisturizing
# 1559
# 1560   Positive:
# Skin: dehydrated, my skin was breaking out
#
# Negative:
# None
# 1561
#
# ### Negative:
# None
#
# Positive:
# Price: more reasonably priced
# Performance: holds over 3 more oz
# Skin: dry patches have already disappeared
# 1562   Negative:
# None
#
# Positive:
# Texture: dreamy, velvety cream
# Price: pricetag
# 1563   Negative:
# None
#
# Positive:
# Skin: dry/dehydrated and sensitive skin, does an amazing job of hydrating and plumping
# Price: uber reasonable
# 1564
#
# ### Positive:
# Skin: keeps my skin soft and glowy
# Texture: doesn’t clog my pores
#
# Negative:
# Application: i can’t use it before i apply my foundation
# 1565
# 1566   Positive:
# Texture: I love this cream. It works great
#
# Negative:
# None
# 1567
# 1568   Negative:
# None
#
# Positive:
# Texture: doesn't leave an oily residue
# 1569   Negative:
# None
#
# Positive:
# Skin: rosacea, dry flaky skin
# 1570   Negative:
# None
#
# Positive:
# Skin: leaves ny skin feeling moisturized and refreshed
# 1571   Negative:
# Skin: made my skin breakout badly
#
# Positive:
# Texture: very creamy
# 1572   Negative:
# None
#
# Positive:
# Skin: dryness/eczema on my cheeks
# Allergy: didn't make me break out
# 1573   Negative:
# Skin: very dry skin
# Allergy: helps even out my skin tone
# Texture: help even out my skin tone
#
# Positive:
# Sentiment: Fan-freaking-tastic
# 1574
#
# ### Positive:
# Skin: so dry, eczema on the bottom of my nose for more than 4 years
# Texture: instantly loved it
# Application: under my make up
#
# Negative:
# None
# 1575   Negative:
# Skin: rosacea,  psoriasis,  oily,  large pores,  putting on make up
# Allergy: smell,  not head over heels for the smell
#
# Positive:
# Skin: less red,  skin re balanced with moisturized texture, less oily,  less dry patches,  less tiny superficial pimples
# Application: putting on make up,  looks hydrated,  not to greasy
# 1576
#
# ### Positive:
# Skin: my skin is so use to the humidity
# Texture: this is gentle enough as a moisturizer for my face
# Application: lotion for the rest of my body
#
# Negative:
# None
# 1577   Negative:
# Skin: dry/sensitive skin
#
# Positive:
# Skin: my skin has never looked better
# 1578
#
# ### Positive:
# Skin: sits great under make up, is the only thing that keeps my skin from drying out
# Allergy: has basically eliminated the red bumps on the back of my arms
#
# Negative:
# None
# 1579
#
#
# 1580   Negative:
# None
#
# Positive:
# Texture: whipped quality to it, so it's not heavy
# Skin: sensitive skin
# 1581
#
# ### Negative:
# None
#
# Positive:
# Skin: my skin feels sooooooo very soft
# Texture: doesn’t break me out, or make me oily
# Application: under my makeup
# 1582
#
# ### Positive:
# Skin: calms my skin, moisturizes without feeling greasy
# Texture: leaves my face feeling amazing
#
# Negative:
# None
# 1583   Positive:
# Skin: acne prone skin
#
# Negative:
# None
# 1584   Negative:
# Skin: my skin did not. If my face hates a product, it will breakout like crazy
# Allergy: caused my foundation to look very greasy
#
# Positive:
# Demographic: neutral scent of the product
# 1585   1. Positive:
#     1. skin: Sahara-Desert-level DRY
#     2. skin: flaky and irritated skin
#     3. skin: lifesaver
#
# Negative:
# None
# 1586
# Skin: dry patches on my face causing discoloration
# Application: Best moisturizer I have ever used
# Texture: thick, but does not leave an oily residue
#
# ### Positive:
# Skin: dry patches on my face causing discoloration
# Application: Best moisturizer I have ever used
# Texture: thick, but does not leave an oily residue
#
# Negative:
# None
# 1587   Negative:
# None
#
# Positive:
# Skin: very dry skin, flakes year round, my skin is very dry
# Texture: great for dry skin
# Price: definitely worth the price
# 1588   Negative:
# Skin: severely dehydrated, extremely flaky
#
# Positive:
# Skin: never been softer
# 1589   Negative:
# Skin: eczema
#
# Positive:
# Sentiment: alleviates redness, peeling, at some point my face was cracked and bleeding due to how dry my eczema was
# 1590
#
# ### Positive:
# Skin: acne-prone, very dry
# Texture: SO SOFT
# Application: after washing your face with FAB’s cleanser
#
# Negative:
# None
# 1591
# Sentiment:
# Skin: dry, oily, normal, and combination skin
# Texture: creamy
# Price: price
#
# Positive:
# Skin: sensitive, irritable skin
# Texture: sink into your skin
# Sentiment:
# Negative:
# 1592
#
# ### Positive:
# Skin: great hydration without the sticky, greasy feeling
#
# Negative:
# None
# 1593   Negative:
# None
#
# Positive:
# Motivation: while also lasting FOREVER!!!!
# 1594   Negative:
# None
#
# Positive:
# Texture: lightweight, moisturizing
# Skin: my boyfriend has even started using it
# Application: tattoo
# 1595
# Positive:
# Skin: sensitive skin that gets oily yet dry
# Texture: doesn’t have much smell
# Price: $30
#
# Negative:
# None
# 1596   Positive:
# Skin: super oily, super sensitive, acne prone skin
# Texture: sinks in so quickly
# Price: Hard to believe but it really is a head to toe moisturizer
#
# Negative:
# None
# 1597   Negative:
# Texture: felt velvety like some people noted
#
# Positive:
# Motivation: attracted by everything the bottle says
# Odor: no-smell smell
# 1598   Positive:
# Skin: extremely moisturizing without the oily after feel
# Texture: leaves my skin looking MATTE
#
# Negative:
# None
# 1599   Positive:
# Skin: combo skin, flaky dry patches, few breakouts
#
# Negative:
# None
# 1600
#
# ### Positive:
# Skin: Calms and soothes itchy eczema flares.
# Demographic: Liked this product so much for my own sporadic rough patches and recurring dishydrotic hand eczema
# Motivation: hoping it would give him some relief
#
# Negative:
# None
# 1601   Negative:
# Skin: my skin felt so hydrated
#
# Positive:
# Sentiment: started using this
# 1602   Positive:
# Skin: super soft and clear
#
# Negative:
# None
# 1603   Positive:
# Skin: helps a lot with my dry skin
#
# Negative:
# None
# 1604   Positive:
# Skin: skin is very sensitive, red and almost everything burns
# Texture: no burning
#
# Negative:
# None
# 1605   Negative:
# None
#
# Positive:
# Texture: adds nice moisture for sensitive skin
# 1606
# ### Positive:
# Skin: my face really dry
#
# Negative:
# None
# 1607   Negative:
# Skin: minor irritation on my skin
#
# Positive:
# Skin: felt moisturized
# Skin: did not leave a greasy residue
# 1608
#
# ### Positive:
# Skin: very dry skin
# Application: during the winter
#
# Negative:
# None
# 1609
#
# ### Negative:
# None
#
# Positive:
# Skin: sensitive and dry skin, super universal
# Odor: scent, thickness of the cream
# 1610
# Positive:
# Skin: stubborn dry skin, helped hydrate even the most difficult dry spots
# Texture: totally gone
# Sentiment: My boyfriend will use this
# 1611   Negative:
# Skin: really really dry skin
#
# Positive:
# Purchase: repurchased this moisturizer at least 4 or 5 times
# Application: First Aid Beauty you guys rock ❤️
# 1612   Negative:
# None
#
# Positive:
# Texture: Go-to Mousturizer
# 1613
#
# ### Positive:
# Skin: skin is not used to the weather here plus the hormonal changes that happens to me every year cause I was also pregnant last year
#
# Negative:
# None
# 1614   Artery:
# Skin: winter makes his knuckles crack and bleed
#
# ### Negative:
# None
#
# Positive:
# Texture: soft
# 1615   Negative:
# None
#
# Positive:
# Skin: really helped my dry skin
# Texture: makeup go on smooth
# 1616
#
# 1617   Positive:
# Skin: dry hands from the cold weather
# Texture: works great on my dry hands
#
# Negative:
# None
# 1618   Negative:
# None
#
# Positive:
# Skin: calms my stressed out, sensitive, redness prone skin
# Texture: thick consistency, but sinks into my skin
# Allergy: does not make me break out
# 1619   Negative:
# Skin: combo skin with acne
#
# Positive:
# Texture: my face felt like it had a thicker moisturizer
# Skin: super smooth, got rid of a couple acne spots
# 1620   Negative:
# Packaging: wish I could buy it in the 2mL (.06 fl oz) packages
#
# Positive:
# None
# 1621   Artery:
# Skin: soft supple skin that is no longer screaming for hydration
# Texture: like whip cream
# Odor: no more flakes
# Texture: not even irritation or redness
# 1622   Negative:
# None
#
# Positive:
# Skin: pretty dry skin, finding a good moisturizer is nearly impossible
# Texture: large container means you are getting the most value for your buck
# Application: only takes 1-2 swipes of the cream to cover the face
# 1623   Negative:
# Skin: my skin isn't to bad
# Allergy: some stuff makes me break out
#
# Positive:
# Motivation: my skin soft
# 1624   Negative:
# None
#
# Positive:
# Skin: an allergic reaction to an eye cream
# Allergy: only product that seemed to help
# Purchase: buy this regularly
# Packaging: use it as a nighttime moisturizer/ spot treatment for dry areas of skin
# 1625   Positive:
# Texture: tube only
#
# Negative:
# Odor: eucalyptus-y
# 1626   Negative:
# None
#
# Positive:
# Skin: dry skin, so hydrating
# Texture: locks in moisture
# 1627   Negative:
# Allergy: doesn't skin moisturized throughout the day
#
# Positive:
# Skin: sinks into my skin well, doesn't leave a greasy film
# 1628   Negative:
# None
#
# Positive:
# Skin: hydrates my face instantly, use it daily
# 1629
#
# ### Positive:
# Skin: My skin has been so dry and flaky for the past few months, as soon as I started using this I saw a trendeous change! My skin hasn’t felt this good in a while
#
# Negative:
# None
# 1630   Negative:
# None
#
# Positive:
# Skin: my skin feels so soft
# Texture: works like high end
# Price: per ounce
# 1631   Negative:
# None
#
# Positive:
# Skin: sensitive skin
# Demographic: my mother in law
# 1632
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1633   Negative:
# None
#
# Positive:
# Skin: combination skin, dry eczema patches
# Texture: unscented, light-whipped
# Allergy: preggo!
# 1634   Negative:
# None
#
# Positive:
# Texture: BEST moisturizing cream for everything
# Application: husband uses it
# Packaging: larger jars
# 1635
# 1636
# Positive:
# Skin: eczema & acne, takes care of the eczema on my face neck & body
# Allergy: doesn’t make me break out
# Price: wish it was less expensive
#
# Negative:
# None
# 1637   Negative:
# Texture: quite heavy
# Allergy: prescription retin-a
#
# Positive:
# Skin: keeps my dry skin hydrated
# Texture: doesn't cause me to break out
# 1638
# Positive:
# Skin: skin feels velvety soft
#
# Negative:
# None
# 1639   Positive:
# Skin: combo skin, an oily T zone, normal everywhere else
#
# Negative:
# None
# 1640   Positive:
# Skin: best face moisturizer out there
#
# Negative:
# None
# 1641   Positive:
# Skin: extra dry, sensitive skin, winter is rough on my skin
# Texture: heavy, not in a bad way that irritates or promotes acne
# Purchase: one every winter
# Skin: instantly smoother, looks great a few days in
#
# Negative:
# None
# 1642
# Rating: 5/5:
#
# Positive: skin, moisturizer, Perfect, balanced moisturizer
#
# Negative:
# Allergy: skin has been acting very strange
# 1643   Negative:
# None
#
# Positive:
# Skin: dry, red patches on my face
# Texture: not thick
# 1644
#
# ### Positive:
# Skin: smoother and healthier, it’s cruelty free
#
# Negative:
# None
# 1645
#
# ### Positive:
# Skin: dry/patchy skin, minimize my dry patches
# Texture: looks thick at first glance, but when you put it on your skin feels very moisturized
# Allergy: doesn’t bother my sensitive skin
#
# Negative:
# None
# 1646   Rating: 5
#   END:
#
# ### Positive:
# Skin: healed my face really well
# 1647
# 1648
#
# ### Positive:
# Skin: extremely sensitive skin
# Allergy: doesn’t break out in itchy bumps
# Texture: keeps me hydrated
#
# Negative:
# None
# 1649
# Sentiment:
# Positive:
# Skin: best thing for my skin so far
# Texture: whipped consistency of the cream
# Application: before I put on makeup
# Texture: really intense hydration
# Sentiment:
# Price: price for the amount of product
# 1650   Positive:
# Skin: my skin has been inflamed
# Texture: pretty thick
# Skin: my face doesn't look tight
# Oily spots: my oily spots aren't oilier
#
# Negative:
# None
# 1651   Negative:
# None
#
# Positive:
# Skin: looking for a good night moisturizer
# Price: only $36!
# 1652   Negative:
# None
#
# Positive:
# Skin: very sensitive skin, doesn't clog my pores, doesn't make me breakout
# Texture: creamy and thick when it goes on, feels lightweight
# 1653   Negative:
# None
#
# Positive:
# Skin: extremely moisturized, my face feel extremely moisturized, extremely dry skin
# Texture: helped stop my skin from peeling
# 1654   Negative:
# None
#
# Positive:
# Skin: very dry skin, break out in hives frequently
# 1655   Negative:
# None
#
# Positive:
# Skin: soothed my skinned, calmed down the redness
# Texture: a little product goes a long way
# 1656   Negative:
# Skin: more oil than it already does
#
# Positive:
# Skin: feel refreshed
# Motivation: night cream
# 1657
#
# ### Positive:
# Skin: perioral dermatitis, FAB radiance pads
# Price: magical price
#
# Negative:
# None
# 1658   Positive:
# Skin: adds hydration I want without clogging pores & creating more breakouts
# Price: fraction of the price
#
# Negative:
# None
# 1659
# ### Positive:
# Skin: dry patches, flakiness
#
# Negative:
# None
# 1660   Positive:
# Skin: sensitive skin
#
# Negative:
# None
# 1661
#
# ### Negative:
# None
#
# Positive:
# Skin: perfect for when your skin is dry and and it doesn’t leave ur skin oily
# 1662
# 1663
# Positive:
# Skin: sinks in so quickly, keeps your skin soft and hydrated
#
# Negative:
# None
# 1664
#
# ### Positive:
# Skin: moisture locked in, causes ZERO irritation, no breakouts
# Application: put this on, gloves before bed
#
# Negative:
# None
# 1665   Negative:
# None
#
# Positive:
# Texture: doesn't leave me oily
# Price: given how long it'll last
# 1666
# 1667   Negative:
# Skin: flaky, driest, most red, sensitive skin
#
# Positive:
# Skin: dry patches, skin so soft, glowy
# 1668   Negative:
# None
#
# Positive:
# Skin: dry skin, the product is thick but not oily
# Texture: loing lasting
# 1669   BAD: None
#
#   NEUTRAL: None
#
#   GOOD: for winter dryness
#
# #### END
#
# ### Negative:
# None
#
# Positive:
# Texture: soaks in after a while
#
# Negative:
# None
#
# Positive:
# Application: winter dryness
# 1670
#
# ### Positive:
# Skin: clearing all beautiful
#
# Negative:
# None
# 1671   Negative:
# None
#
# Positive:
# Skin: really bad eczema
# 1672   Negative:
# None
#
# Positive:
# Skin: sensitive skin or allergies
# Price: reasonable
# 1673   Positive:
# Skin: can use it on your face, body, everywhere!
# Texture: does not break me out!
# Allergy: eczema spot on my arm
# 1674   Negative:
# None
#
# Positive:
# Skin: dried out after trying a skincare system, flaky face, not a flake in sight
# Texture: doesn't leave my skin feeling slimy or greasy
# Application: my hands, elbows, or feet have had a particularly rough day
# 1675   Negative:
# None
#
# Positive:
# Skin: dry skin gone, redness calmed, breakouts clearing up
# Demographic: my rosacea is completely under control
# 1676
# 1677   Negative:
# None
#
# Positive:
# Price: cheaper for much more
# Skin: way more hydrating
# 1678   Negative:
# None
#
# Positive:
# Texture: a little bit goes a long way
# Skin: this is it
# 1679   Positive:
# Skin: sensitive skin, broke out
#
# Negative:
# Skin: sensitive skin
# 1680   Negative:
# Skin: quite oily, but cold weather does tend to dry it out
# Allergy: didn't break me out
#
# Positive:
# Skin: My skin is quite oily, but cold weather does tend to dry it out
# Texture: blended and dried into the skin without too much rubbing
# Application: Love how my skin feels after applying it
# 1681   Positive:
# Skin: extremely dry, irritated, dry, red in spots, not good
# Texture: super balanced
#
# Negative:
# None
# 1682   Positive:
# Skin: works well for my skin in the winter
#
# Negative:
# None
# 1683   Negative:
# Skin: my skin is still dry
#
# Positive:
# Sentiment: use of natural ingredients
# 1684   Negative:
# None
#
# Positive:
# Skin: my skin has never felt so moisturized
# Texture: Ultra Repair Cream dries quickly
# 1685   1. Positive:
#     1. eczema
#     2. oatmeal
#     3. skin care routine
#     4. does not get oily
#     5. does not feel uncomfortable
#   2. Negative:
#     1. Positive:
#     1. not find a face moisturizer
#     2. oatmeal
#     3. soothes, moisturizes, and treats my face
#     4. does not get oily
#     5. does not feel uncomfortable
#
# ### Negative:
# None
#
# Positive:
# Skin: eczema, oatmeal
# Allergy: eczema
# Texture: does not get oily
# Application: summer
# 1686   Negative:
# None
#
# Positive:
# Skin: eczema patches on my body
# 1687   Negative:
# None
#
# Positive:
# Skin: dry skin with red and sensitive parts
# 1688
#
# ### Positive:
# Skin: dry skin
#
# Negative:
# None
# 1689   Negative:
# None
#
# Positive:
# Skin: combination skin, dry patches
# 1690   Positive:
# Texture: really like this cream
# Skin: too heavy for my face
#
# Negative:
# Application: causes me to become too oily
# 1691   Positive:
# Skin: The best rich moisturizer ever used
#
# Negative:
# None
# 1692
#
# ### Positive:
# Skin: dry skin, great for my sensitivities
# Texture: extra layer of moisture
# Application: helps me with my dry skin
#
# Negative:
# None
# 1693   END USER REVIEWS:
#     Positive: I love it!
#     Negative: But it can pill under makeup.
#
# ### Action Items
#
# -   See if there is a way to make the pill dissolve under makeup
# -   See if there is a way to make the pill dissolve under makeup
#
# ### Positive:
# -   I love it!
#
# Negative:
# -   But it can pill under makeup.
#
# ### END USER:
# Skin:
# Allergy:
# 1694
#
# 1695
#
# ### Positive:
# Skin: red bumps on my arms due to eczema, skin has never looked better
# Texture: moisturizes the skin beautifully
#
# Negative:
# None
# 1696   Negative:
# None
#
# Positive:
# Texture: whipped texture feels so nice going on
# Price: so affordable
# 1697
#
# ### Positive:
# Skin: driest/most sensitive skin, tones down the oil on my nose
# Texture: hydrated without being greasy
# Application: First Aid Beauty!
#
# Negative:
# None
# 1698   Negative:
# None
#
# Positive:
# Texture: simultaneously is the creamiest, most hydrating cream
# Skin: super dry skin, not clogging pores, not causing breakouts
# Price: Affordable
# 1699
#
# ### Negative:
# None
#
# Positive:
# Skin: less flaky, hydrated/moisturized glow
# 1700
# #### Positive:
# Application: Amazing product. A little goes a long way and it’s worth the investment!
# 1701   Positive:
# Skin: combination skin dry cheeks, Tzone oily
# Texture: not make me break out
#
# Negative:
# None
# 1702   Positive:
# Skin: patches of dry skin on my face during the winter time
# Application: within the hour, my skin would be patchy again
# Motivation: save money and go to the drugstore
#
# Negative:
# None
# 1703
#
# ### Positive:
# None
#
# Negative:
# Skin: extremely thin, balls up because of the silicone
# 1704   Negative:
# None
#
# Positive:
# Skin: super dry skin
# 1705   Positive:
# Skin: absorbs well, keeps my hands soft
#
# Negative:
# None
# 1706   Positive:
# Skin: eczema, dry, sensitive skin
# Allergy: helps with redness
#
# Negative:
# None
# 1707   Positive:
# None
#
# Negative:
# Skin: made my already oily acne-prone skin oilier, break out
# 1708   Negative:
# None
#
# Positive:
# Skin: combination skin, holy grail moisturizer
# 1709   Skin: red spots on my face
#   END: cleared up
#   DATE: May 2019
#
# Positive:
# Skin: red spots on my face
# 1710
#
# ### Positive:
# Skin: completely transformed my dry skin
# Application: use it on my face but you can use it anywhere
# Texture: light enough to use everyday
#
# Negative:
# None
# 1711
# ### Negative:
# None
#
# Positive:
# None
# 1712   Positive:
# Skin: really dry skin, super hydrated
# Allergy: super hydrated
#
# Negative:
# None
# 1713   Negative:
# Skin: made my entire face break out
#
# Positive:
# None
# 1714
# Positive:
# Skin: my favorite moisturizer, especially for the price
#
# Negative:
# None
# 1715   Positive:
# Skin: super hydrating in the dry areas, didn't make the oily areas in my t-zone even oilier
# Allergy: didn't irritate it one bit
#
# Negative:
# None
# 1716   Positive:
# Skin: extremely dry skin
#
# Negative:
# None
# 1717   Negative:
# None
#
# Positive:
# Skin: my dry face, especially in the winter!
# 1718
# 1719   Negative:
# None
#
# Positive:
# Skin: so hydrated, my skin so hydrated
# Texture: makes my skin so hydrated
# 1720   Positive:
# Purchase: based on great reviews
# Packaging: no-fuss which means also you will be able to use every last drop
# Skin: my usually sensitive skin has no reaction
# Texture: whipped creamy consistency
# 1721
#
# ### Negative:
# None
#
# Positive:
# Skin: rosacea, very sensitive and tends towards dry
# Texture: absorbs into my skin without being greasy
# 1722   Negative:
# None
#
# Positive:
# Skin: completely cleared up my dry skin issues, reduced the redness in my cheeks, also seems to help with outbreaks
# Allergy: tattoo cream, minimizes that itchy dryness without you feeling the need to constantly apply it
# 1723
#
# ### Negative:
# None
#
# Positive:
# Skin: super dry skin
# Allergy: allergic to most skincare brands
# Texture: skin is so soft
# Application: doesn’t break out
# 1724   Negative:
# None
#
# Positive:
# Skin: eczema on my hands that gets really bad in the winter
# Texture: gentle enough to use on my combination skin face at night
# Price: probably
# 1725   Negative:
# None
#
# Positive:
# Texture: makes my face feel so soft, like a baby's
# Skin: hydrates so well!!
# 1726   Negative:
# None
#
# Positive:
# Application: face and body
# 1727   Positive:
# Skin: does a good job of moisturizing
# Allergy: reminds me of Noxzema cream
#
# Negative:
# Odor: smells like Noxzema cream
# 1728   Negative:
# None
#
# Positive:
# Skin: cleared up, more hydrate
# 1729   Negative:
# None
#
# Positive:
# Skin: my winter skin, super dry skin
# Texture: creamy, hydrating
# Odor: smell nothing too gross
# 1730   Negative:
# None
#
# Positive:
# Skin: spots of eczema on my hands, alleviating the drying and cracking associated with both winter and eczama
# Texture: doesn't irritate
# 1731   Positive:
# Skin: wind burn from skiing
#
# Negative:
# None
# 1732   Negative:
# None
#
# Positive:
# Skin: acne prone and combo skin, eczema on my hands
# Texture: quickly heal my acne scars
# 1733
#
# ### Positive:
# None
#
# Negative:
# Texture: doesn’t help my dry patches, in fact it makes it appear worse
# 1734   Positive:
# Skin: calmed my skin, cured most of my breakout overnight
# Allergy: not caused any irritation
#
# Negative:
# None
# 1735   Positive:
# Skin: small sample of this in my Ipsy bag
#
# Negative:
# None
# 1736   Negative:
# Skin: EXTREMELY oily
#
# Positive:
# None
# 1737   Negative:
# None
#
# Positive:
# Texture: has just enough weight to be soothing
# Skin: dry, flaky, itchy, red patches
# Price: outstanding too
# 1738
#
# ### Positive:
# Skin: combination skin that can breakout on occasion
# Texture: thick when you need your extra dry skin repaired
#
# Negative:
# None
# 1739   Positive:
# Skin: sensitive, eczema prone skin, doesn't seem to clog pores
#
# Negative:
# None
# 1740   Positive:
# Skin: eczema, definitely see an improvement in his skin
#
# Negative:
# None
# 1741
# 1742
# Positive:
# None
#
# Negative:
# Price: had to ignore the amount I got for the price
# Skin: actually think of getting something around same price that would actually offer my skin benefits
# 1743
# Sentiment: way it makes my face feel rejuvenated
# Skin: combo skin, with my forehead being more oily
# Texture: ultra repair cream
# Packaging: I bought the extra big tub of this during Black Friday
# 1744   Negative:
# None
#
# Positive:
# Skin: hydrates my skin instantly, leaves it glowing
# 1745
#
# ### Positive:
# Skin: Holy grail! Such a bargain. I use it daily on my chest and neck. I also use it on my face when it’s feeling a little dry. It absorbs quickly and leaves your skin so soft and hydrated.
#
# Negative:
# None
# 1746   Negative:
# None
#
# Positive:
# Skin: my very combination skin
# Texture: my very combination skin
# 1747   Negative:
# None
#
# Positive:
# Texture: sinks in fast
# Skin: skin feels comfortable
# 1748   Negative:
# None
#
# Positive:
# Skin: super dry in the winter, also have problems with eczema
# 1749   Negative:
# Skin: dry/combination skin
#
# Positive:
# Skin: doesn't make my skin feel oily
# 1750
#
# ### Positive:
# Skin: Doesn’t give a dewy glow
#
# Negative:
# None
# 1751   Positive: love, skin, sensitive combination skin, moisturizer
#   Neg: nothing
#
# ### Negative:
# Skin: sensitive combination skin
# 1752   Positive:
# Texture: not greasy
# Skin: not break me out
#
# Negative:
# None
# 1753   Negative:
# Skin: my skin condition that flakes
#
# Positive:
# Skin: without being at all greasy
# 1754   Negative:
# None
#
# Positive:
# Texture: Feels so good!
# 1755   Negative:
# None
#
# Positive:
# Skin: combination and acne prone skin, gives amazing hydration
# 1756   Negative:
# Skin: normal/combo skin, got very dry
# Allergy: eczema
#
# Positive:
# Skin: fix the dry patches on my face
# 1757   Negative:
# None
#
# Positive:
# Brand: bought this awhile ago as a whim
# Texture: slight scent
# 1758   Negative:
# None
#
# Positive:
# Skin: dry and sensitive skin
# 1759   Negative:
# None
#
# Positive:
# Skin: my skin is beautiful,soft, dewy
# Texture: tiniest on days where my skin is a little dry before makeup
# 1760
# ### Positive:
# Skin: healed a few incoming pimples
#
# Negative:
# None
# 1761
#
# ### Positive:
# Skin: eczema, cleared in one week
#
# Negative:
# None
# 1762
# 1763   Positive:
# Skin: dry, sensitive, acneic skin, has to endure the harsh Wisconsin winter
# Texture: very moisturizing without being greasy, soft airy
# Odor: very nice subtle smell from the eucalyptus oil, has a very soft airy
# Sentiment: love it so much
# Price: budget friendly "high end" skincare brand
#
# Negative:
# None
# 1764   Negative:
# None
#
# Positive:
# Skin: sensitive skin, don't like strong perfume smelling lotions
# 1765   Positive:
# Skin: face, body not face
#
# Negative:
# Allergy: broke out the next day after 1st time use
# 1766   Negative:
# Skin: did absolutely nothing for my skin
# Allergy: had no adverse effects
#
# Positive:
# None
# 1767
#
# ### Positive:
# Skin: leaves my skin feeling so soft!
#
# Negative:
# None
# 1768   Negative:
# Skin: didn't feel as though it hydrated my skin
#
# Positive:
# Motivation: little cheaper than other moisturizers
# 1769   Negative:
# None
#
# Positive:
# Texture: absorbs quickly
# Skin: doesn't have a scent!
# 1770   Negative:
# None
#
# Positive:
# Texture: does not leave a greasy feel
# Performance: immediately soaks into skin
# 1771   Negative:
# None
#
# Positive:
# Skin: my skin has become really dry from my Retin-A
# Texture: thick cream with no fragrance, just simple and effective
# 1772
# Rating: 5
#
# ### Positive:
# Skin: insanely dry, from my forehead to around my mouth
# Texture: not heavy on the skin
# Odor: natural odor
#
# Negative:
# None
# 1773   Negative:
# None
#
# Positive:
# Skin: extremely dry skin
# 1774   Negative:
# None
#
# Positive:
# Skin: dry skin, does wonders for my dry skin
# 1775   1. Positive:
#     1. dry patches
#     2. winter
#     3. layer of moisturizer
#     4. doesn't get oily
#     5. wedding day
#   2. Negative:
#     1. nothing
#
# ### Negative:
# Texture: nothing
# Skin: dry patches
# Application: layer of moisturizer
# 1776   Positive:
# Skin: really hydrates your face
# Texture: thick
#
# Negative:
# Allergy: smells weird
# 1777   Negative:
# Skin: leaves my face feeling greasy, doesn't leave my skin feeling hydrated at all
# Allergy: also, I found the claim that it hydrates dry skin and relieves minor irritation
# Performance: Any minor irritation or dryness I had was only made worse by this product
#
# Positive:
# None
# 1778
# Application:
# Skin: skin has been having issues for the last like 6 months really bad
# Texture: this has helped SO MUCH.
#
# ### Positive:
# Skin: my skin has pretty much stopped breaking out completely
# Texture: this is lightening all of my dark spots as well
# 1779   Negative:
# None
#
# Positive:
# Texture: non-irritating moisturizer
# 1780   Negative:
# Skin: pilling in general, pills like CRAZY
# Allergy: prone to pilling
#
# Positive:
# Skin: mostly combo skin hydrated
# 1781   Negative:
# None
#
# Positive:
# Skin: sensitive combination skin, without making my skin too oily
# Texture: without making my skin too oily
# Allergy: has a reaction
# 1782   Negative:
# None
#
# Positive:
# Texture: my hands were extremely dry and flaky
# 1783   Negative:
# Skin: dry dry and sensitive skin
# Allergy: though if there is roughness
#
# Positive:
# Skin: hydrates without feeling greasy or tacky
# 1784
#
# ### Positive:
# Skin: keeps my skin moisturized
# Skin: doesn’t break me out
# Skin: has also worked wonders on helping my baby’s “baby acne”
#
# Negative:
# None
# 1785   Negative:
# None
#
# Positive:
# Texture: lightweight, not greasy
# 1786
#
# ### Positive:
# None
#
# Negative:
# Skin: began breaking out more, feel very tacky on my skin
# 1787   Negative:
# Skin: dry and sensitive skin
#
# Positive:
# Application: 2oz minis at Sephora on sale
# 1788   Negative:
# Skin: my face feeling oily and greasy like
#
# Positive:
# None
# 1789   Negative:
# None
#
# Positive:
# Skin: moisturizes my skin, properly moisturizes my skin
# 1790   Negative:
# None
#
# Positive:
# Skin: completely non-irritating on my sensitive, eczema prone, rosacea having skin
# Texture: skin soothing oatmeal
# Allergy: non-irritating
# 1791
# 1792
# Performance: absorbs immediately (which as per most skin estheticians I’ve been to for facials is a key to a great product)
# Texture: Love!
# Allergy: None
# 1793
#
# ### Positive:
# Skin: My skin is back to normal, maybe even slightly oily again
# Texture: quickly absorbed
#
# Negative:
# None
# 1794
#
# ### Positive:
# Skin: super dry skin, dry it was practically flaking off
# Skin: my skin has never felt softer
# Skin: makeup applies so much better
# Application: instant results
#
# Negative:
# None
# 1795   Rating:
#
# Positive: effectiveness, worth the price
#
# Negative: None
# 1796
#
# ### Positive:
# Skin: flesh-colored bumps on my forehead
# Texture: cleared them after only a DAY of use
# Application: BEST DECISION I HAVE EVER MADE
#
# Negative:
# None
# 1797   Positive:
# Skin: dry skin, eczema, helps her dry skin
# Allergy: breaks me out
#
# Negative:
# Application: use it on my toddler
# 1798   Rating: 5/5
#
# ###  END
#
# ### Price:
#
# ###  Cost: $0
#
# ###  END
#
# ###  Source:
#
# ###  END
#
# ###  Taste:
#
# ###  END
#
# ###  Texture:
#
# ###  END
#
# ###  Price:
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###  END
#
# ###
# 1799
# Positive:
# Skin: extremely dry skin, does leave my skin slightly sticky
# Texture: very nice amount for how much you pay
#
# Negative:
# None
# 1800
#
# ### Positive:
# Skin: Makes my skin feel so hydrated
#
# Negative:
# None
# 1801   Negative:
# None
#
# Positive:
# Skin: sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive skin, sensitive
# 1802   Negative:
# None
#
# Positive:
# Texture: it has made a world of difference to the feel of my face
# Skin: my boyfriend even uses it
# 1803   Negative:
# Texture: prefer the tub to the tube
#
# Positive:
# Skin: cracked heels, wind-burned cheeks
# 1804
#
# 1805   Positive:
# None
#
# Negative:
# Skin: super dry this winter
# 1806
#
# ### Positive:
# None
#
# Negative:
# Texture: balled up
# Skin: balling up, white spots
# 1807   Negative:
# Skin: My face was very dry and flaky, I used the Ultra Repair
# Allergy: My face was very dry and flaky
# 1808   Negative:
# None
#
# Positive:
# Skin: breakouts around my eyes, prevent them
# Texture: tiny tube lasts forever
# Allergy: has also prevented them
# 1809   Negative:
# None
#
# Positive:
# Texture: not a super heavy moisturizer
# Skin: revived, super soft/smooth
# 1810
# 1811   Negative:
# Skin: my skin was so dry and flaky this winter
#
# Positive:
# Skin: my skin was so dry and flaky this winter
# Allergy: so far no issues or breakouts
# 1812
# ### Positive:
# Skin: had really bad eczema on my hands
#
# Negative:
# None
# 1813   Positive:
# Skin: my skin was so dry
# Texture: not dry at all anymore
#
# Negative:
# None
# 1814
# Positive:
# None
#
# Negative:
# Price: $30
# Performance: doesn’t notice any lasting benefits
# Texture: feels heavy and greasy
# 1815   Negative:
# None
#
# Positive:
# Skin: combo skin- dehydrated, acne, cleared up my breakouts in DAYS
# 1816
# 1817   Negative:
# None
#
# Positive:
# None
# 1818
#
# ### Positive:
# Skin: combination skin, winters here in Michigan make the dry areas even drier
# Skin: dry areas that were flakey, itchy, and painful
# Skin: dry, flakey areas weren’t itchy and didn’t hurt anymore
# Sentiment: I’ve gotten a lot of compliments on my skin
#
# Negative:
# None
# 1819   Positive:
# Skin: clogged my pores
#
# Negative:
# Allergy: combination sensitive skin
# 1820   Negative:
# None
#
# Positive:
# Skin: combo skin (oily tzone and dry cheeks) gal
# Texture: doesn't break me out
# Application: nice on random dry spots
# 1821   Negative:
# None
#
# Positive:
# Texture: feels really soft
# 1822   Negative:
# None
#
# Positive:
# Texture: leaves your skin feeling soft and moist
# 1823   Positive:
# Texture: mix it with face oil
#
# Negative:
# Odor: smells bad
# 1824
#
# ### Negative:
# Texture: too heavy as a face cream
#
# Positive:
# Alternate use: cracked hands
# 1825   Negative:
# Texture: don't like the waxy smell
# Application: hard to apply to my face evenly
#
# Positive:
# None
# 1826
#
# ### Positive:
# None
#
# Negative:
# Skin: Doesn’t absorb well on face
# Allergy: Doesn’t absorb very well on face
# Texture: moisturizer flakes of
# 1827   Negative:
# None
#
# Positive:
# Skin: HG for the winter months, and even the rest of the year.
# Texture: soaks in fast
# Allergy: don't make my hands feel greasy
# 1828
#
# ### Positive:
# Skin: smell is relaxing, not too strong, not greasy
# Application: dries fast
#
# Negative:
# None
# 1829   Positive:
# Skin: eczema sufferers
#
# Negative:
# None
# 1830   Negative:
# None
#
# Positive:
# Skin: dry skin, esp in the winter, this is a great hydrater, esp for the price
# 1831
#
# ### Positive:
# Skin: hydrates, it calms, it soothes
# Texture: unscented
#
# Negative:
# None
# 1832   Negative:
# None
#
# Positive:
# Texture: really acts as a great sealant for other products on my skin
# Packaging: little goes a long way
# 1833
# 1834
# 1835
#
# ### Positive:
# Skin: sensitive skin
#
# Negative:
# None
# 1836
# ### Positive:
# Skin: sensitive skin, cracked hands, hard to do anything about it
# Ingredients: hard to find in a lot of drug store “hydration creams”
# Texture: literally the only cream I’ve ever used that’s stuck to its word of “helping hydrate dry, parched skin”
#
# Negative:
# None
# 1837
# 1838   Negative:
# None
#
# Positive:
# Skin: extra sensitive dry skin
# 1839   Negative:
# Texture: appears to be a little oily
#
# Positive:
# Performance: great hydration
# 1840   Positive:
# Texture: great moisture
#
# Negative:
# Texture: feels greasy
# Odor: smell is off-putting
# 1841
#
# ### Positive:
# Skin: Sensitive skin, moisturizer
# Texture: squeeze tube of it lasts me months!
# Application: Exfoliate after cleansing
#
# Negative:
# None
# 1842   Negative:
# None
#
# Positive:
# Skin: extremely dry skin, bad redness, terrible eczema around my lips
# Price: COMPLETELY worth it
# 1843   Positive:
# Skin: calming & hydrating
#
# Negative:
# None
# 1844
#
# ### Positive:
# Skin: acne, no scent
#
# Negative:
# None
# 1845
#
# ### Positive:
# Skin: skin will really smooth and relaxed
# Application: don’t apply it everyday
# Demographic: tried the smallest size
#
# Negative:
# None
# 1846
# Positive:
#  Packaging: Can’t believe how cheap this is for the amount of product I got!
#
# Negative:
# None
# 1847   Positive:
# Skin: soaks right in, isn't greasy or clogging
# Texture: amazing
#
# Negative:
# None
# 1848   Negative:
# None
#
# Positive:
# Texture: sat on my beauty cabinet
# Skin: nummular eczema
# Purchase: almost done with the huge tub
# 1849   Negative:
# Skin: not for skin care routine
#
# Positive:
# None
# 1850   Negative:
# Allergy: sensitive dry skin
#
# Positive:
# Skin: sensitive dry skin
# 1851   Negative:
# None
#
# ...
# 2321   Negative:
# Skin: super dry skin, especially under my eyes
#
# Positive:
# Skin: super soft, makeup looks so much better
# 2322   Negative:
# None
#
# Positive:
# Skin: super sensitive, prone to acne,
# Skin: improved hydration
# Sentiment: almost erased acne breakouts
# 2323   Positive:
# Skin: peeling tattoo
#
# Negative:
# None
# 2324   Negative:
# Skin: moved from Hong Kong, I found it difficult to keep my skin hydrated like before in RI
#
# Positive:
# Skin: more hydrated apparently
# 2325   Positive:
# Skin: my face feels so soft!
#
# Negative:
# None
# 2326   Positive:
# Skin: really dry skin
#
# Negative:
# None
# 2327   Negative:
# None
#
# Positive:
# Price: at an even better price
# Packaging: 2 in 1
# Skin: face, body
# 2328   Negative:
# Allergy: SUPER sensitive
# Odor: off putting "plastic-y" scent
#
# Positive:
# Skin: my dry patches
# 2329   Positive:
# Skin: no more flakiness, redness, or dry patches!
#
# Negative:
# None
# 2330   Negative:
# None
#
# Positive:
# Skin: extremely dry skin, very sensitive
# 2331   Negative:
# Skin: very very dry skin
#
# Positive:
# Sentiment: recommended to me
# 2332   1. Positive:
#     1. repaired, restored, strengthened
#     2. completely
#     3. skin
#     4. getting rid of all dryness
#     5. love
#     6. amazing
#   2. Negative:
#     1. cost a pretty penny
#     2. didn't want to waste any money
#
# ### Negative:
# None
#
# Positive:
# Motivation: desperate for a good face lotion
# Skin: super dry crackly skin
# 2333
# ### Negative:
# None
#
# Positive:
# Skin: My skin looks better
# 2334   Negative:
# None
#
# Positive:
# Motivation: had the WORST dry patches
# Sentiment: thank GOODNESS I bought this
# 2335   Negative:
# Skin: combination dry/oily skin
# Application: way too heavy on my face
#
# Positive:
# Demographic: cold dry desert winter
# 2336
# 2337   Negative:
# None
#
# Positive:
# Texture: thicker cream
# 2338   Negative:
# Skin: horrible acne, combination skin
#
# Positive:
# Skin: dryness, seemingly helped balance my skin out a bit more
# Application: use it for my hands
# 2339
# 2340   Negative:
# Skin: no reaction using this with other products
# Allergy: make sure to stop sticking your hands into the jar
#
# Positive:
# Skin: more moisturizing
# Texture: 8 oz tube
# 2341   Positive: winter in Virginia, super dry hands, fairly thick cream
#   Neg: would not use it on my face, didn't use it for my body
#   END
#
# Overall:
# Skin: winter in Virginia, super dry hands, fairly thick cream
# Texture: fairly thick cream
# 2342   Negative:
# None
#
# Positive:
# Skin: miracle worker, extremely dry, overnight, my skin had improved
# 2343   Positive:
# None
#
#   Negative:
# Skin: combination skin, my cheeks and forehead can get really dry and sensitive
# Allergy: eucalyptus oil, where it sit there, it can irritate the skin
# Motivation: now is you have normal skin
# 2344   Negative:
# None
#
# Positive:
# Motivation: I'm in love with this stuff
# Skin: psoriasis on my arms
# 2345   Positive:
# None
#
# Negative:
# Performance: seems to have caused a few small pimples to show up on my face
# 2346   Negative:
# None
#
# Positive:
# Texture: Nice Creamy Smooth Cream
# 2347   Negative:
# Skin: most angry, red, broken out skin
# Allergy: patchy
#
# Positive:
# Skin: moisturizer, moisturizer, moisturizer
# Motivation: bartend, unflattering lights
# 2348   Negative:
# None
#
# Positive:
# Skin: battle random bouts of psoriasis, eyelids, general eye area, especially during wintertime
# Texture: dabbed a tiny bit during my most recent psoriasis flareup
# Allergy: it showed major signs of calming down
# Application: routine application
# Performance: it significantly improved daily
# 2349   Positive:
# None
#
# Negative:
# Skin: acne in places I've never gotten acne before
# Allergy: made me break out
# 2350
# 2351   Positive:
# Skin: dry patches, skin with foundation looked really bad
# Texture: cold weather it worked really well
#
# Negative:
# None
# 2352   1. Positive:
#     1. skin care products
#     2. Allure
#     3. blow my mind
#     4. $50-$75 moisturizers
#     5. up there
#   2. Negative:
#     1. price
#
# ### Negative:
# Competitor: $50-$75 moisturizers
#
# ### Positive:
# Motivation: skin care products
# 2353   Positive:
# Skin: dry skin on my arms/legs/feet from the cold
# Texture: unscented, doesn't irritate my sensitive skin
#
# Negative:
# None
# 2354   Negative:
# None
#
# Positive:
# Skin: dryness, skin is left feeling very soft
# 2355   Negative:
# None
#
# Positive:
# Texture: doesn't even matter, SAVES. LIVES.
# 2356   Armpit: Allergy, dry skin
#   END: Allergy
#
# ### Negative:
# None
#
# Positive:
# Texture: slather it on everywhere
# 2357   Positive:
# Skin: oily skin, acne
#
# Negative:
# Skin: didn't work for me
# 2358   Negative:
# None
#
# Positive:
# Skin: super dry, saved my skin
# 2359   Negative:
# None
#
# Positive:
# Texture: thick consistency
# Skin: makes my skin flawless
# Purchase: Will repurchase
# 2360   Negative:
# None
#
# Positive:
# Skin: completely saved my dry skin in the winter!
# 2361   Negative:
# Skin: no signs of aging
#
# Positive:
# Texture: doesn't change
# 2362   Negative:
# Skin: skin broke out very severely
#
# Positive:
# None
# 2363   Positive:
# Skin: unusual dry patches all over my face
# Texture: transformed my skin overnight
# Application: bought this product over and over
# Price: repurchased this product over and over
#
# Negative:
# None
# 2364   Positive: Skin: my skin is now almost clear
#   END: acne is now almost clear
#   Motivation: Kathleen lights from YouTube recommended this stuff
#   Negative: None
#
# ### Negative:
# Skin: hormonal acne all over my chin and jawline
#
# Positive: END: acne is now almost clear
# Motivation: Kathleen lights from YouTube recommended this stuff
# 2365   Positive:
# Skin: crazy combo skin, the dry is REALLY dry, the oily is REALLY oily!
# Demographic: started retin-a
# Skin: peeling skin
# 2366   Positive:
# Skin: gave it a try, very happy on my purchase
#
# Negative:
# None
# 2367   Negative:
# Skin: very sensitive skin
# Allergy: doesn't use perfumes
#
# Positive:
# Skin: keeps it moisturized
# 2368   Negative:
# None
#
# Positive:
# Skin: such a huge fan of these moisturizer!
# Texture: Love how it feels on my skin after
# Allergy: doesn't increase oil onto my face during the day
# 2369   Negative:
# Texture: not greasy or oily
#
# Positive:
# Motivation: pay the price
# 2370
# 2371
# Sent:
# 2372   Positive: skin: crazy dry skin, flake, eczema
#   Negative: nothing
# 2373   Negative:
# Allergy: my forehead started to get really dry, itchy, and irritated
#
# Positive:
# Motivation: started using this little guy
# Texture: super lightweight
# 2374
# 2375   Negative:
# None
#
# Positive:
# Motivation: This is the best lotion I ever bought in my life.
# 2376   Negative:
# None
#
# Positive:
# Skin: oily skin, one of the only moisturizer that is working for my skin
# 2377   Negative:
# None
#
# Positive:
# None
# 2378   Negative:
# None
#
# Positive:
# Skin: extremely sensitive skin
# Texture: non greasy
# 2379   Negative:
# None
#
# Positive:
# Texture: doesn't have a ton of additives
# 2380   Negative:
# None
#
# Positive:
# Texture: reasonably priced, generous amount
# Skin: ultra moisturizing
# 2381   Negative:
# Skin: super dry as in skin-flakes-shedding dry
#
# Positive:
# Skin: repair my skin over night
# 2382   Positive:
# Skin: very moisturizing
#
# Negative:
# None
# 2383   1. Positive:
#     1. skin: dry & flaky
#     2. not heavy or oily
#     3. spf
#     4. make-up
#   2. Negative:
#     1. not heavy or oily
#
# ### Negative:
# None
#
# Positive:
# Skin: dry & flaky, not heavy or oily, spf, make-up
# 2384
# 2385   Negative:
# None
#
# Positive:
# Skin: such a huge fan of these moisturizer
# Texture: doesn't leave a sticky layer on top
# 2386
# 2387   Positive:
# Skin: wake up with refreshed, hydrated skin
#
# Negative:
# None
# 2388   Negative: skin, Seborrheic Dermatitis
#
# Positive: Accutane, didn't use this sooner
# 2389   Negative:
# Skin: so dry and oily
#
# Positive:
# Skin: tried everything
# Sentiment: I am so glad I did
# 2390   Positive:
# Texture: does a good job of providing moisture
# Skin: avoid greasiness
#
# Negative:
# Allergy: flaky
# Purchase: not sure if I will be repurchasing
# 2391   Negative:
# None
#
# Positive:
# Skin: super moisturizing, still feels light on the skin
# Demographic: used their cleanser as well
# 2392   Positive:
# Skin: didn't break me out, didn't moisturise my face
#
# Negative:
# Odor: medicinal smell, other smell
# Application: my face does not feel moisturised the next morning
# 2393   Negative:
# Allergy: allergic reactions
#
# Positive:
# Skin: super dry skin, super soft
# 2394   Negative:
# None
#
# Positive:
# Skin: extremely sensitive skin
# 2395   Negative:
# None
#
# Positive:
# Skin: wake up with my skin feeling soft
# 2396   Positive:
# Skin: instantly fell in love with this product
# Skin: constantly dried out from the chlorine
# Sentiment: totally recommend
#
# Negative:
# None
# 2397   Positive:
# Texture: doesn't break me out, my skin stays moisturized
#
# Negative:
# None
# 2398   Negative:
# None
#
# Positive:
# Skin: sensitive skin, prone to breakouts
# Texture: bit on the heavier side
# 2399   Negative:
# Skin: my skin is so dry
# Texture: super heavy
# Sentiment: didn't like the feel of it
# 2400   1. 1.  Apply: all over face
#   2. 2.  Ingredients:
#     1. a. Glycerin: helps to keep skin moist
#     2. b. Water: helps to keep skin moist
#     3. c. Glycolic Acid: helps to remove dead skin cells
#     4. d. Allantoin: helps to prevent skin from drying out
#     5. e. Sodium PCA: helps to prevent skin from drying out
#     6. f. Sodium PCA: helps to prevent skin from drying out
#     7. g. Allantoin: helps to prevent skin from drying out
#
# ### Negative:
# Skin: extremely dry skin
# Allergy: little bumps on my cheeks
#
# Positive:
# Skin: helps to keep skin moist
# Texture: makes you skin so smooth
# 2401   Positive:
# Skin: combination skin, constantly oily in my t zone
# Texture: absorbs, almost instantly calms the redness
#
# Negative:
# None
# 2402   Negative:
# None
#
# Positive:
# Skin: SUPER sensitive
# 2403   Positive:
# Skin: sensitive skin that gets dry in the winter
# Price: price totally justified
#
# Negative:
# None
# 2404   Negative:
# None
#
# Positive:
# Texture: Provides the absolute perfect amount of moisture
# Price: superb value
# 2405   Negative:
# None
#
# Positive:
# Texture: so rich and hydrating
# Application: sinks into the skin quickly
# Skin: hasn't changed in three years, it's that good
# Allergy: incredibly gentle and non-irritating
# 2406   Negative:
# Skin: didn't absorb into my skin
# Texture: balled up in my fingers
#
# Positive:
# None
# 2407   Positive: cleared my eczema, left no marks
#
# Negative:
# None
# 2408   1. Positive:
#     1. skin: tone and texture of skin
#   2. Negative:
#     None
#
# ### Negative:
# Application: can not wait to try more FAB products
#
# ### Positive:
# Motivation: holy grail of moisturizers
# Skin: tone and texture of skin
# 2409   Positive:
# Skin: skin is hydrated for the first time ever
# Skin: my skin is beaming!
#
# Negative:
# None
# 2410   Positive:
# Skin: combination skin - oily in the center and dry everywhere else
# Texture: calms down the redness, dryness and itchiness
#
# Negative:
# None
# 2411   Negative:
# Skin: oily mostly in the center of my face
# Allergy: was stubbornly dry
#
# Positive:
# Texture: crack!
# Sentiment: Absolutely love it
# 2412   Positive:
# Skin: dyfrate my skin, will be buying the big size soon:)
#
# Negative:
# None
# 2413   Negative:
# Texture: doesn't make my face feel oily, sticky, or heavy
# Allergy: doesn't make my face feel oily
#
# Positive:
# Skin: dry, uneven skin
# Texture: lightweight
# 2414   Positive:
# Skin: combo oily skin, cheeks get so incredibly dry
# Texture: instantly calms it, epilate my face
# Application: lathering myself in it all day
# Skin: chicken skin on my upper arms
# 2415   Negative:
# None
#
# Positive:
# Skin: really dry skin, especially living in Texas, where there is absolutely no moisture in the air
# Texture: so hydrating and smooth, and it absorbs into the skin
# Allergy: cleared my skin up quite a bit
# 2416   Negative:
# Skin: winter dryness, my sister started using this too
# Allergy: little bumps (tiny pimples all over her face)
# Texture: doesn't absorb well
#
# Positive:
# None
# 2417   Positive:
# Skin: so smoothing, felt so hydrated
#
# Negative:
# None
# 2418   Negative:
# None
#
# Positive:
# Skin: dry skin, really helps my dry skin
# Texture: not much product is needed to suffice the entire face
# 2419   Negative:
# Skin: weirdest dry patches on my face
#
# Positive:
# Skin: made my skin feel so supple
# Allergy: didn't irritate that dry patch
# 2420   Negative:
# None
#
# Positive:
# Skin: bit of eczema, apply this even just once a day
# Allergy: decrease the redness, smooth away the dry bumpy texture
# Habit: bad habit of licking my lips
# 2421   Negative:
# Skin: my skin wasn't hydrating
#
# Positive:
# Purchase: tried this guy out
# Texture: thick
# 2422   Negative:
# None
#
# Positive:
# Skin: moisturizer, winter, dry skin, hydrated, glow
# 2423   Negative:
# Allergy: little bumps on my forehead
#
# Positive:
# None
# 2424   Negative:
# None
#
# Positive:
# Skin: pregnancy, dry skin
# 2425   Positive:
# Skin: going through some changes, my skin becoming very dry, have had dry patches that became red and flakey, my skin is very sensitive
# Allergy: no reactions to this cream
# Skin: never had any breakouts
# Skin: my skin looking great all day
# Application: can use it on my face and body
# Sentiment: Highly recommend giving this a try
# Motivation: my mom gave me this
#
# Negative:
# None
# 2426   Negative:
# Skin: drying my skin out
#
# Positive:
# Motivation: Affordable
# Odor: did the job
# 2427   Negative:
# Skin: irritated from a new product
#
# Positive:
# Skin: feels 10 times better
# 2428   Negative:
# None
#
# Positive:
# Texture: feels like I had just put a face primer on
# Skin: normal to dry skin
# 2429   Positive:
# Skin: acne prone skin
# Price: reasonably priced
#
# Negative:
# None
# 2430   Negative:
# Skin: get rid of itchy
#
# Positive:
# Skin: my skin is back to dry, patchy
# 2431   Positive:
# Skin: very dry skin - everywhere
# Texture: Provides great moisture without oily or greasy texture
# Price: price cannot be beat
#
# Negative:
# None
# 2432   1. Positive:
#     1. skin: lots of redness, my cheeks gets seriously dehydrated
#     2. skin: my cheeks gets seriously dehydrated
#     3. skin: plumped, hydrated, firm
#     4. skin: taught me something (who knew skincare could teach, right?)
#     5. skin: not the most expensive ones
#     6. skin: not the most expensive ones
#     7. Negative:
#     1. skin: Irish heritage, and that I was pretty much stuck with red irritated skin
#     2. END
#
# Positive: END
#
# Negative:
# Skin: Irish heritage, and that I was pretty much stuck with red irritated skin
# 2433   Positive:
# Skin: used to moisturize before makeup routine, after the shower all over body, used on my infant after baths
#
# Negative:
# None
# 2434   Negative:
# Skin: dry, acne prone skin
#
# Positive:
# Skin: intense boost of hydration
# 2435   Negative:
# None
#
# Positive:
# Skin: essential for all skin types, especially combination and dry skin!
# Texture: dries to a natural finish
# 2436   Negative:
# None
#
# Positive:
# Skin: essential for all skin types, especially combination and dry skin!
# Texture: dries to a natural finish
# 2437   Negative:
# None
#
# Positive:
# Skin: Winter skin, tired skin, airplane-on the road dehydration solved!
# 2438   Positive: hydrated hands, dry winter
#   Negative: no lotion has seemed to help
# 2439   Positive: hydrated hands, dry winter
#   Neg:
# Allergy: no lotion has seemed to help
# 2440   Negative:
# None
#
# Positive:
# Skin: extremely dry and sensitive skin
# 2441   Negative:
# None
#
# Positive:
# Skin: extremely dry and sensitive skin
# 2442   Positive:
# Skin: combination skin, flaky skin, softer skin
#
# Negative:
# None
# 2443   Negative:
# None
#
# Positive:
# Motivation: I ordered a sample size of this just so I had $25 worth of stuff in my cart
# Skin: neck is starting to sag
# Demographic: 41
# 2444   Positive: skin, eczema, lotion
#   Negative: None
#
# ### Negative: END:
#
# Overall: skin, eczema, lotion
#
# Positive: END:
#
# Negative: END:
# 2445   Positive:
# Skin: neck is starting to sag
#
# Negative:
# None
# 2448   Positive:
# Skin: dry patches, especially in the winter
#
# Negative:
# None
# 2449   Negative:
# Skin: so comfortable after using this cream!
#
# Positive:
# Skin: helps take down the redness
# Skin: stops breakouts

# %% [markdown]
# # completion processing

# %%
df['Negative']=''
df['Positive']=''

for i in df.index:
    if type(df['completion'][i])==float:
        continue
    l1 = df['completion'][i].split('###')
    if len(l1)>=2:
        l = df['completion'][i].split('###')[1].split('\n\n')
    else:
        l = df['completion'][i].split('\n\n')
    if(len(l)==1):
#         print(i,df['completion'][i],l)
        continue
#     if l[0]=='':
#         l.pop(0)
#     if l[0][1]=='#':
#         l[0] = l[0][3:]
    l[0] = l[0].strip()
#     print(i)
    try:
        if l[0][0].lower()=='n':
            df['Negative'][i] = l[0]
            df['Positive'][i] = l[1]
        else:
            df['Negative'][i] = l[1]
            df['Positive'][i] = l[0]
    except:
        pass
        
df['Negative'] = df['Negative'].str.split('Negative: ',expand=True)[1]
df['Positive'] = df['Positive'].str.split('Positive: ',expand=True)[1]
df['Negative'] = df['Negative'].str.split('\n')
df['Positive'] = df['Positive'].str.split('\n')

# %% [markdown]
# # Aspect count per sentiment

# %%
n_aspect={}
p_aspect={}

for i in df2.index:
    for senti in ['Positive','Negative']:
        l = df2[senti][i]
    #     print(i)
        if l is None or (len(l)==0 or len(l)==1):
            continue
        if l[0]=='':
            l.pop(0)
        if senti=='Negative':
            for j in l:
                try:
                    n_aspect[j.split(':')[0]]+=1           
                except:
                    n_aspect[j.split(':')[0]]=1           
        else:
            for j in l:
                try:
                    p_aspect[j.split(':')[0]]+=1           
                except:
                    p_aspect[j.split(':')[0]]=1 
del p_aspect['None']
del n_aspect[' END']

negative_aspects = pd.DataFrame(n_aspect.values(),index=n_aspect.keys(),columns=['count'])
positive_aspects = pd.DataFrame(p_aspect.values(),index=p_aspect.keys(),columns=['count'])

negative_aspects.to_csv('negative_aspects_count.csv')
positive_aspects.to_csv('positive_aspects_count.csv')

# %% [markdown]
# # completion df -> txt file

# %%
df2.fillna('',inplace=True)
df2['prompt']='##'+df2['Review ID']+'\n'+df2['Review Title']+'\n'+df2['Review']+'##ENDING##\n\n\n'+df2['completion']+'\n'
st = ''
for i in df2.index:
    st=st+df2['prompt'][i]
# print(st)

text_file = open("output_txt.txt", "w",encoding="utf8") 
text_file.write(st)
text_file.close()

# %%
df2['Rating'] = pd.read_csv('P4 first aid beauty.csv')['Rating'].str.split(' ',expand=True)[0]
df2['Review ID'] = pd.read_csv('P4 first aid beauty.csv')['Review ID']
# Out:
# <ipython-input-354-f75a17e180b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Rating'] = pd.read_csv('P4 first aid beauty.csv')['Rating'].str.split(' ',expand=True)[0]

# %% [markdown]
# # completion df layer 2 (summary)

# %%
# df = pd.read_csv('data_P4_first_aid_beauty.csv',index_col=0)
# df.drop(['Review ID','Rating'],1,inplace=True)
daf = pd.read_csv('P4 first aid beauty.csv')
# index = df.index
df = pd.merge(df,daf.loc[:,['Review','Review ID','Date','Rating']],on='Review')
# df.index = df['key_0']
# df.drop(['key_0'],1,inplace=True)
df.drop_duplicates(['Review ID'],inplace=True)
# df.index = index
# for i in df.index:
#     if type(df['Review Title'][i])!=float:
#         df['Review'][i] = df['Review Title'][i]+'\n\n'+df['Review'][i]
# df.drop([711,712,713,998,1048],inplace=True)
# df.fillna('',inplace=True)
# df.drop_duplicates(['Review'],inplace=True)
df['Rating'] = df["Rating"].apply(lambda x : int(x.split()[0]))

# %%
# for i in df.index:
#     for senti in ['Negative','Positive']:
#         if df[senti][i]==['','None'] or df[senti][i]==['','None',''] or df[senti][i]==None:
#             df[senti][i]=[]
#         print(i)
#         try:
#             if ' END' in df[senti][i]:
#                 df[senti][i].remove(' END')        
#         except:
#             print(i)
#             pass
            
resultlist=[]
for i in df.index:
    for senti in ['Positive','Negative']:
#         print(i,df[senti][i])
#         print(df[senti][i] is None)
        if df[senti][i] is None or type(df[senti][i])==float:
            continue
        for aspects in ast.literal_eval(df[senti][i]):
#         for aspects in df[senti][i]:
#             print("aspects:",aspects)
            aspect = aspects.split(':')[0]
#             if len(aspect)==1 or len(aspects)==0:
#                 continue
#             print(aspect,i)
            try:
                phrases = aspects.split(':')[1]
            except:
                continue
#             print("phrases:",aspects.split(':')[1])
            for phrase in phrases.split(','):
                result={}
                result['Review ID'] = df['Review ID'][i]
                result['sentiment'] = senti
                result['Review'] = df['Review'][i]
                result['Rating'] = df['Rating'][i]
                result['Date'] = df['Date'][i]
#                 if phrase==' None':
# #                     print(aspects)
#                     continue
                result['phrase'] = phrase
                result['aspect'] = aspect
                resultlist.append(result)
df3 = pd.DataFrame.from_dict(resultlist, orient='columns')
df3['Rating'] = df3['Rating'].astype(int)
df3.drop_duplicates(inplace=True)
df3 = df3.sort_values(['sentiment','aspect'],ascending=False)
df3.index = range(len(df3))
# aspect_count = {}
# for review in df3.Review.unique():
#     for aspect in df3[df3.Review==review]['aspect'].unique():
#         try:
#             aspect_count[aspect]+=1
#         except:
#             aspect_count[aspect]=1
            
# x = pd.DataFrame(df3.groupby('aspect').count().sort_values(['Review'],ascending=False)['phrase'])
# x.columns = ['phrase_count']
# y = df3.groupby(['aspect']).mean()
# y.columns = ['phrase_avg_rating']
# w = df3.groupby(['aspect','Review']).mean().groupby(['aspect']).mean()
# w.columns = ['review_avg_rating']
# z = pd.DataFrame(aspect_count.values(),index=aspect_count.keys(),columns=['review_count'])

# final_df = x.join(y).join(z).join(w)
# final_df.to_csv('gptj_20221224v1.csv')
# final_df

# %% [markdown]
# # detailed_output

# %%
df = pd.read_csv('data_P4_first_aid_beauty.csv',index_col=0)#.loc[:1374]
df.drop(['Review ID','Rating'],1,inplace=True)

# %%
l = detailed_output(df)
# Out:
# Processing Completed
#
# Phrase Dataframe Created
#
# Clustering Started
#
# BERTopic Clustering will take a while
# Sentiment: Positive Aspect: Texture
#             Cluster
# cream            64
# skin             49
# greasy           42
# heavy            37
# not greasy       36
# absorb           26
# thick            22
# oily             18
# texture          16
# Sentiment: Positive Aspect: Temperature
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Positive Aspect: Super dry skin
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Positive Aspect: Substitute
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Positive Aspect: Skin
#                     Cluster
# skin                    125
# dry skin                 86
# eczema                   68
# sensitive skin           57
# moisturize               55
# hydrating                52
# dry                      46
# redness                  38
# flare                    33
# acne prone               28
# dryness                  27
# hydrate                  26
# extremely dry skin       25
# acne                     24
# oily                     23
# crack                    23
# patch                    20
# combination skin         20
# flaky                    17
# rosacea                  16
# sensitive                14
# dry sensitive            14
# itchy                    14
# winter                   13
# irritation               12
# super scaly              12
# Sentiment: Positive Aspect: Sentiment
#              Cluster
# love              68
# moisturizer       24
# cream             23
# holy grail        20
# Sentiment: Positive Aspect: Sent
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Positive Aspect: Purchase
#       Cluster
# buy        39
# size       15
# one         9
# Sentiment: Positive Aspect: Price
#                 Cluster
# price                63
# worth                16
# not beat price        1
# Sentiment: Positive Aspect: Performance
#              Cluster
# skin              48
# hour              22
# improvement       14
# Sentiment: Positive Aspect: Packaging
#          Cluster
# last          23
# tube          16
# product       11
# Sentiment: Positive Aspect: Odor
#            Cluster
# smell           28
# scent           17
# fragrance       15
# Sentiment: Positive Aspect: Motivator
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Positive Aspect: Motivation
#                   Cluster
# sephora                36
# sample                 27
# review                 14
# know anyway glad       11
# Sentiment: Positive Aspect: Ingredients
#             Cluster
# ingredient       23
# Sentiment: Positive Aspect: Demographic
#           Cluster
# husband        41
# winter         29
# pregnant       21
# dry            19
# live           12
# month          12
# Sentiment: Positive Aspect: Competitor
#        Cluster
# cream       14
# Sentiment: Positive Aspect: Brand
#        Cluster
# brand       34
# Sentiment: Positive Aspect: Application
#         Cluster
# makeup       87
# face         23
# skin         17
# Sentiment: Positive Aspect: Allergy
#        Cluster
# skin        27
# break       19
# Sentiment: Positive Aspect: Age
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Positive Aspect: Customer
# Sentiment: Positive Aspect:  END
# Clustering done after 73.84 sec
# Sentiment: Negative Aspect: Texture
#         Cluster
# skin         27
# greasy       15
# white        11
# Sentiment: Negative Aspect: Temperature
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Negative Aspect: Super dry skin
# Sentiment: Negative Aspect: Substitute
# Sentiment: Negative Aspect: Skin
#             Cluster
# acne             35
# dry              33
# pore             30
# moisturize       20
# oily             13
# sensitive        11
# Sentiment: Negative Aspect: Sentiment
#      Cluster
# not       13
# Sentiment: Negative Aspect: Sent
# Sentiment: Negative Aspect: Purchase
#      Cluster
# not       11
# Sentiment: Negative Aspect: Price
#            Cluster
# expensive       13
# Sentiment: Negative Aspect: Performance
#      Cluster
# not       23
# Sentiment: Negative Aspect: Packaging
#       Cluster
# wish       21
# Sentiment: Negative Aspect: Odor
#        Cluster
# smell       32
# Sentiment: Negative Aspect: Motivator
# Sentiment: Negative Aspect: Motivation
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Negative Aspect: Ingredients
#             Cluster
# eucalyptus       14
# Sentiment: Negative Aspect: Demographic
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Negative Aspect: Competitor
#                Cluster
# cream               18
# cerave              13
# pricy product        7
# Sentiment: Negative Aspect: Brand
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Negative Aspect: Application
#       Cluster
# face       25
# Sentiment: Negative Aspect: Allergy
#         Cluster
# pimple       26
# break        19
# burn         18
# seem         10
# Sentiment: Negative Aspect: Age
# Sentiment: Negative Aspect: Customer
# Aspect contains only one phrase. BERTopic Error.
#
# Sentiment: Negative Aspect:  END
# Aspect contains only one phrase. BERTopic Error.
#
# Clustering done after 116.98 sec
# Layer 2 Completed
#
# Layer 1 Completed
#
# Excel File with 4 sheets is created.

# %%
s = df3[(df3.aspect=='Skin')&(df3.sentiment=='Positive')]
s['Month'] = s.Date.str[3:]

nlp = spacy.load("en_core_web_sm")
docs = list(s.loc[:, "phrase"].values)
# ", ".join(stopwords.words('english'))
    
def tokenization(text):
    tk = WhitespaceTokenizer()
    return tk.tokenize(text)

docs = pd.Series(docs).apply(lambda x: tokenization(x))

#Stop words present in the library
# stopwords = nltk.corpus.stopwords.words('english')
stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your',
 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 
'its','itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 
'these','those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did',
'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 
'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how',
'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'nor', 'only', 'own', 'same', 'so', 'than', 'too',
'very', 's', 't','can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 
'ain', 'aren', "aren't",'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven',
 "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', 
 "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'since','first','last', 'even',
 'thisssss', 'could','really','always','bc','truly','literally','48','none','yet','actually','like','would','ever','issss',
'although','much','10','do','super'] # 'not','no'

#defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output
 
#applying the function for removal of stopwords
docs = docs.apply(lambda x:remove_stopwords(x))

for i in range(len(docs)):
    docs[i] = " ".join(docs[i]) 

# Lemmatization
for i in range(len(docs)):
    doc = nlp(docs[i])
    tokens = []
    for token in doc:
        tokens.append(token)
    lemmatized_sentence = " ".join([token.lemma_ for token in doc])
    docs[i] = lemmatized_sentence
#     print(lemmatized_sentence)

# s_model = SentenceTransformer('all-MiniLM-L6-v2',device='cpu')
modal = BERTopic(n_gram_range=(1,3),language="english")
topics, probs = modal.fit_transform(docs)

s['Cluster']=''
s.index=range(len(s))
predicted_topics, predicted_probs = modal.transform(docs)
for i in range(len(s)):
    y = modal.get_topic(predicted_topics[i])[0][0]
    l = y.split()
    k = []
    for x in l:
        if (y.count(x)>=1 and (x not in k)):
            k.append(x)
    s['Cluster'][i] = ' '.join(k)

# %%
data
# Out:
#              acne  acne prone  combination skin  dry  dry sensitive  dry skin  \
# Month
# 01_Nov_2018     1           2                 0    2              0         1
# 01_Dec_2018     1           2                 0    5              1         7
# 01_Jan_2019     2           3                 0    5              1        10
# 01_Feb_2019     1           1                 2    4              0         5
# 01_Mar_2019     0           1                 1    4              0         6
# 01_Apr_2019     2           3                 0    3              1         8
# 01_May_2019     0           1                 2    4              2         7
# 01_Jun_2019     2           1                 0    3              0         2
# 01_Jul_2019     1           2                 1    1              2         3
# 01_Aug_2019     1           1                 1    4              0         0
# 01_Sep_2019     0           0                 2    4              0         0
# 01_Oct_2019     2           0                 0    1              1         4
# 01_Nov_2019     2           0                 0    1              1         4
# 01_Dec_2019     0           0                 1    4              1         2
# 01_Jan_2020     0           2                 1    3              0         4
# 01_Feb_2020     0           1                 0    3              0         3
# 01_Mar_2020     1           2                 1    6              1         2
# 01_Apr_2020     0           2                 2    5              0         5
# 01_May_2020     0           1                 1    7              0         6
# 01_Jun_2020     3           0                 3    1              1         2
# 01_Jul_2020     2           0                 1    4              1         4
# 01_Aug_2020     2           1                 1    1              1         1
#
#              eczema  extremely dry skin  flaky  hydrate  ...  moisturize  \
# Month                                                    ...
# 01_Nov_2018       1                   1      2        1  ...           1
# 01_Dec_2018       6                   2      0        2  ...           7
# 01_Jan_2019       9                   2      0        2  ...           9
# 01_Feb_2019       8                   1      1        1  ...           5
# 01_Mar_2019       3                   1      0        3  ...           1
# 01_Apr_2019       5                   0      0        2  ...           5
# 01_May_2019      10                   2      0        3  ...           2
# 01_Jun_2019       0                   0      2        1  ...           3
# 01_Jul_2019       5                   1      0        1  ...           1
# 01_Aug_2019       4                   2      0        0  ...           2
# 01_Sep_2019       1                   0      0        0  ...           1
# 01_Oct_2019       3                   0      0        1  ...           0
# 01_Nov_2019       6                   1      1        0  ...           2
# 01_Dec_2019       7                   0      2        1  ...           2
# 01_Jan_2020       8                   3      2        0  ...           0
# 01_Feb_2020       0                   0      1        0  ...           2
# 01_Mar_2020       8                   0      2        0  ...           0
# 01_Apr_2020       8                   3      2        3  ...           3
# 01_May_2020       4                   1      0        0  ...           3
# 01_Jun_2020       4                   0      1        1  ...           1
# 01_Jul_2020       1                   0      2        3  ...           4
# 01_Aug_2020       4                   0      1        1  ...           0
#
#              oily  patch  redness  rosacea  sensitive  sensitive skin  skin  \
# Month
# 01_Nov_2018     2      0        1        0          0               1     5
# 01_Dec_2018     2      1        1        1          0               3     6
# 01_Jan_2019     4      3        3        1          0               4    12
# 01_Feb_2019     1      2        3        0          0               3    15
# 01_Mar_2019     0      0        1        1          1               2     8
# 01_Apr_2019     1      2        2        1          3               4     8
# 01_May_2019     1      1        4        1          0               5     8
# 01_Jun_2019     0      0        0        1          1               3     7
# 01_Jul_2019     0      1        0        1          1               3     7
# 01_Aug_2019     0      0        0        0          0               4     7
# 01_Sep_2019     0      0        0        0          2               1     1
# 01_Oct_2019     0      0        0        0          0               0     4
# 01_Nov_2019     0      0        2        0          0               3     5
# 01_Dec_2019     3      0        0        0          1               2     6
# 01_Jan_2020     1      1        1        1          0               1    13
# 01_Feb_2020     1      1        0        0          0               1     7
# 01_Mar_2020     0      0        2        2          0               3     7
# 01_Apr_2020     1      1        5        2          0               6     8
# 01_May_2020     0      4        2        2          2               4     5
# 01_Jun_2020     2      1        3        1          0               3     5
# 01_Jul_2020     3      0        4        1          2               1     4
# 01_Aug_2020     1      1        4        0          1               0     1
#
#              super scaly  winter
# Month
# 01_Nov_2018            2       1
# 01_Dec_2018            0       0
# 01_Jan_2019            0       4
# 01_Feb_2019            0       3
# 01_Mar_2019            1       0
# 01_Apr_2019            0       1
# 01_May_2019            0       1
# 01_Jun_2019            0       0
# 01_Jul_2019            0       0
# 01_Aug_2019            1       0
# 01_Sep_2019            0       0
# 01_Oct_2019            0       0
# 01_Nov_2019            0       0
# 01_Dec_2019            1       0
# 01_Jan_2020            1       0
# 01_Feb_2020            0       0
# 01_Mar_2020            1       1
# 01_Apr_2020            1       1
# 01_May_2020            0       0
# 01_Jun_2020            3       0
# 01_Jul_2020            0       1
# 01_Aug_2020            1       0
#
# [22 rows x 23 columns]

# %%
plt.figure(figsize=(25, 10))
plt.xticks(rotation = 45)
data = s.drop(['Rating'],1).join(pd.get_dummies(s['Cluster'])).groupby('Month').sum()
data.reset_index(inplace=True)
data['Month']=pd.to_datetime(data.Month)
data.sort_values(['Month'],inplace=True) 
data['Month'] = data['Month'].apply(lambda x:x.strftime('%d_%b_%Y'))
data['Month'] = data['Month'].str[3:]
data.set_index(['Month'],inplace=True)
sns.lineplot(data=data,markers=True, dashes=False,linewidth =2.3)
sns.set_theme()
plt.ylabel("Phrase Count")
plt.ylim(4, 16)
# Out:
# (4.0, 16.0)

# %%
cluster_count = {}
for review in s.Review.unique():
    for cluster in s[s.Review==review]['Cluster'].unique():
        try:
            cluster_count[cluster]+=1
        except:
            cluster_count[cluster]=1
x = pd.DataFrame(s.groupby('Cluster').count()['phrase'])
x.columns = ['L3 Phrase Count']
y = pd.DataFrame(cluster_count.values(),index=cluster_count.keys(),columns=['L3 Review Count'])
z = pd.DataFrame(s.groupby('Cluster').mean()['Rating'])
z.columns = ['L3 Rating (Phrase)']
a =pd.DataFrame(s.groupby(['Cluster','Review']).mean().groupby('Cluster').mean()['Rating'])
a.columns = ['L3 Rating (Review)']
layer3 = x.join(y).join(z).join(a)
layer3['ClusterID'] = layer3.index
layer3.index=range(len(layer3))
layer3['Cluster'] = layer3.index
layer3.index=range(len(layer3))

# %%
for i in  sheet5[(sheet5['L2 Cluster']=='Skin') & (sheet5[sheet5.Sentiment=='Positive'])].index:
    try:
        c = list(s[s.phrase==sheet5['L4 Phrases'][i]]['Cluster'])[0]
        sheet5['L3 Cluster'][i] = list(layer3[layer3.Cluster==c]['Cluster'])[0]
        sheet5['L3 Phrase Count'][i] = list(layer3[layer3.Cluster==c]['L3 Phrase Count'])[0]
        sheet5['L3 Review Count'][i] = list(layer3[layer3.Cluster==c]['L3 Review Count'])[0]
        sheet5['L3 Rating (Phrase)'][i] = list(layer3[layer3.Cluster==c]['L3 Rating (Phrase)'])[0]
        sheet5['L3 Rating (Review)'][i] = list(layer3[layer3.Cluster==c]['L3 Rating (Review)'])[0]
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-efec6bec1426> in <module>
# ----> 1 for i in  sheet5[(sheet5['L2 Cluster']=='Skin') & (sheet5[sheet5.Sentiment=='Positive'])].index:
#       2     try:
#       3         c = list(s[s.phrase==sheet5['L4 Phrases'][i]]['Cluster'])[0]
#       4         sheet5['L3 Cluster'][i] = list(layer3[layer3.Cluster==c]['Cluster'])[0]
#       5         sheet5['L3 Phrase Count'][i] = list(layer3[layer3.Cluster==c]['L3 Phrase Count'])[0]
#
# NameError: name 'sheet5' is not defined

# %%
l[1][(l[1]['L2 Cluster']=='Skin') & (l[1]['Sentiment']=='Positive')].loc[:,['L3 Cluster','L3 Phrase Count']].sort_values(['L3 Phrase Count'],ascending=False).to_csv('4.csv',index=False)

# %%
def detailed_output(df,cluster_algo='B',cluster_distance=2,date=date.today().strftime('%Y%m%d'),version='v1'):
    #Dataframe should have 'Review' & 'completion' columns, no Review ID & Rating columns
    ########################################dataframe processing##########################
    df['Negative']=''
    df['Positive']=''

    for i in df.index:
        if type(df['completion'][i])==float:
            continue
        l1 = df['completion'][i].split('###')
        if len(l1)>=2:
            l = df['completion'][i].split('###')[1].split('\n\n')
        else:
            l = df['completion'][i].split('\n\n')
        if(len(l)==1):
            continue
        l[0] = l[0].strip()
        try:
            if l[0][0].lower()=='n':
                df['Negative'][i] = l[0]
                df['Positive'][i] = l[1]
            else:
                df['Negative'][i] = l[1]
                df['Positive'][i] = l[0]
        except:
            pass

    df['Negative'] = df['Negative'].str.split('Negative: ',expand=True)[1]
    df['Positive'] = df['Positive'].str.split('Positive: ',expand=True)[1]
    df['Negative'] = df['Negative'].str.split('\n')
    df['Positive'] = df['Positive'].str.split('\n')
    print("Processing Completed\n")
    
    ######################################Phrase Dataframe Creation##############################
    daf = pd.read_csv('P4 first aid beauty.csv')
    df = pd.merge(df,daf.loc[:,['Review','Review ID','Date','Rating']],on='Review')
    df.drop_duplicates(['Review ID'],inplace=True)
    df['Rating'] = df["Rating"].apply(lambda x : int(x.split()[0]))

    resultlist=[]
    for i in df.index:
        for senti in ['Positive','Negative']:
            if df[senti][i] is None or type(df[senti][i])==float:
                continue
            for aspects in df[senti][i]:
                aspect = aspects.split(':')[0]
                try:
                    phrases = aspects.split(':')[1]
                except:
                    continue
                for phrase in phrases.split(','):
                    result={}
                    result['Review ID'] = df['Review ID'][i]
                    result['sentiment'] = senti
                    result['Review'] = df['Review'][i]
                    result['Rating'] = df['Rating'][i]
                    result['Date'] = df['Date'][i]
                    result['phrase'] = phrase
                    result['aspect'] = aspect
                    resultlist.append(result)
    df3 = pd.DataFrame.from_dict(resultlist, orient='columns')
    df3['Rating'] = df3['Rating'].astype(int)
    df3.drop_duplicates(inplace=True)
    df3 = df3.sort_values(['sentiment','aspect'],ascending=False)
    df3.index = range(len(df3))
    print("Phrase Dataframe Created\n")
    
    #########################################sheet5##########################################
    sheet5 = pd.DataFrame(columns=['Sentiment','L1 Cluster ID','L1 Cluster','L1 Phrase Count','L1 Review Count',
                                   'L1 Rating (Phrase)','L1 Rating (Review)','L2 Cluster ID','L2 Cluster','L2 Phrase Count',
                                   'L2 Review Count','L2 Rating (Phrase)','L2 Rating (Review)','L3 Cluster ID','L3 Cluster',
                                   'L3 Phrase Count','L3 Review Count','L3 Rating (Review)','L3 Rating (Phrase)','L4 ID',
                                   'L4 Phrases','Review ID','Review Rating'])
    sheet5['Sentiment'] = df3.sentiment
    sheet5['L2 Cluster'] = df3.aspect
    sheet5['L4 Phrases'] = df3.phrase
    sheet5['Review ID'] = df3['Review ID']
    sheet5['Review Rating'] = df3.Rating
    sheet5 = sheet5.merge(daf.loc[:,['Review ID','Verified Purchase', 'Recommended',
           'Incentivized', 'Upvote', 'Downvote', 'AgeRange', 'SkinConcerns']],on='Review ID')
    sheet5.fillna('',inplace=True)
    print("Clustering Started\n")
    
    #######################################Clustering###########################################
    if cluster_algo=='A':
        for senti in ['Positive','Negative']:
            for aspect in df3.aspect.unique():
                print('Sentiment:',senti,'Aspect:',aspect)
                r = df3[df3.aspect==aspect]
                df1 = r[r.sentiment==senti]
                df1 = df1.reset_index()

                if len(df1)==0:
                    continue

                df1["TempPhraseID"] = range(0, df1.shape[0])
                df1["PhraseID"] = df1.apply(lambda x : "E1" + x["Review ID"][2:] + "P" + str(x["TempPhraseID"]+1), axis = 1)
                corpus_sentences = df1["phrase"].tolist()

                model = SentenceTransformer('all-MiniLM-L6-v2')

                print("Start clustering")
                start_time = time.time()

                print("Encode the corpus. This might take a while")

                corpus_embeddings = model.encode(corpus_sentences, show_progress_bar=True)
                # Normalize the embeddings to unit length
                corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)

                clustering_model = AgglomerativeClustering(n_clusters=None, distance_threshold=cluster_distance) 
                #, affinity='cosine', linkage='average', distance_threshold=0.4)
                try:
                    clustering_model.fit(corpus_embeddings)
                except:
                    continue
                clusters = clustering_model.labels_
                clustersWithID = list(map(lambda x : x[::-1], enumerate(list(clusters))))

                print("Clustering done after {:.2f} sec".format(time.time() - start_time))
                d = {"Less Than 5" : 0, 
                     "Less Than 10" : 0,
                     "Less Than 20" : 0,
                     "Less Than 30" : 0,
                     "Less Than 40" : 0,
                     "Less Than 100" : 0,
                     "Less Than 200" : 0}
                print("Number of Clusters : ", len(set(clusters)))
                print("Phrases Used : ", len(clustersWithID))
                print("\n")

                tempDict = Counter(clusters)

                for clusterId in tempDict:
                    if tempDict[clusterId] <= 5:
                        d["Less Than 5"] += 1
                    elif tempDict[clusterId] <= 10:
                        d["Less Than 10"] += 1
                    elif tempDict[clusterId] <= 20:
                        d["Less Than 20"] += 1
                    elif tempDict[clusterId] <= 30:
                        d["Less Than 30"] += 1
                    elif tempDict[clusterId] <= 40:
                        d["Less Than 40"] += 1
                    elif tempDict[clusterId] <= 100:
                        d["Less Than 100"] += 1
                    elif tempDict[clusterId] <= 200:
                        d["Less Than 200"] += 1

                print(*d.items(), sep = "\n")
                print("\n")
                for i, j in sorted(tempDict.items(), key = lambda x : -x[1]):
                    print("Cluster - {} : {}".format(i, df1["phrase"][list(clusters).index(i)]))

                clusterDF = pd.DataFrame(clustersWithID, columns = ["ClusterID", "TempPhraseID"])
                finalDFWithClusters = pd.merge(df1, clusterDF, on='TempPhraseID', how='inner')
                print(finalDFWithClusters)
                cluster_count = {}
                for review in finalDFWithClusters.Review.unique():
                    for cluster in finalDFWithClusters[finalDFWithClusters.Review==review]['ClusterID'].unique():
                        try:
                            cluster_count[cluster]+=1
                        except:
                            cluster_count[cluster]=1

                x = pd.DataFrame(finalDFWithClusters.groupby('ClusterID').count()['phrase'])
                x.columns = ['L3 Phrase Count']
                y = pd.DataFrame(cluster_count.values(),index=cluster_count.keys(),columns=['L3 Review Count'])
                z = pd.DataFrame(finalDFWithClusters.groupby('ClusterID').mean()['Rating'])
                z.columns = ['L3 Rating (Phrase)']
                a =pd.DataFrame(finalDFWithClusters.groupby(['ClusterID','Review']).mean().groupby('ClusterID').mean()['Rating'])
                a.columns = ['L3 Rating (Review)']
                layer3 = x.join(y).join(z).join(a)
                layer3['ClusterID'] = layer3.index
                layer3.index=range(len(layer3))

                layer3['Cluster']=''
                for i in range(len(layer3)):
                    layer3['Cluster'][i] = df1["phrase"][list(clusters).index(i)]

                layer3 = layer3.iloc[:,[4,5,0,1,2,3]]

                s = sheet5[sheet5.Sentiment==senti]
                for i in  s[s['L2 Cluster']==aspect].index:
                    try:
                        cid = list(finalDFWithClusters[finalDFWithClusters.phrase==sheet5['L4 Phrases'][i]]['ClusterID'])[0]
                        sheet5['L3 Cluster ID'][i] = cid
                        sheet5['L3 Cluster'][i] = list(layer3[layer3.ClusterID==cid]['Cluster'])[0]
                        sheet5['L3 Phrase Count'][i] = list(layer3[layer3.ClusterID==cid]['L3 Phrase Count'])[0]
                        sheet5['L3 Review Count'][i] = list(layer3[layer3.ClusterID==cid]['L3 Review Count'])[0]
                        sheet5['L3 Rating (Phrase)'][i] = list(layer3[layer3.ClusterID==cid]['L3 Rating (Phrase)'])[0]
                        sheet5['L3 Rating (Review)'][i] = list(layer3[layer3.ClusterID==cid]['L3 Rating (Review)'])[0]
                    except:
                        pass
    else:
        print("BERTopic Clustering will take a while")
        nlp = spacy.load("en_core_web_sm")
        stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your',
         'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 
        'its','itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 
        'these','those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did',
        'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 
        'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
        'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how',
        'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'nor', 'only', 'own', 'same', 'so', 'than', 'too',
        'very', 's', 't','can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 
        'ain', 'aren', "aren't",'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven',
         "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', 
         "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'since','first','last', 'even',
         'thisssss', 'could','really','always','bc','truly','literally','48','none','yet','actually','like','would','ever','issss',
        'although','much','10','do','super'] # 'not','no'
        def tokenization(text):
            tk = WhitespaceTokenizer()
            return tk.tokenize(text)
        def remove_stopwords(text):
            output= [i for i in text if i not in stopwords]
            return output
        
        start_time = time.time()
        for senti in ['Positive','Negative']:
            for aspect in df3.aspect.unique():
                print('Sentiment:',senti,'Aspect:',aspect)
                r = df3[df3.aspect==aspect]
                df1 = r[r.sentiment==senti]
                df1 = df1.reset_index()
                if len(df1)==0:
                    continue
                    
                docs = list(df1.loc[:, "phrase"].values)
                docs = pd.Series(docs).apply(lambda x: tokenization(x))
                docs = docs.apply(lambda x:remove_stopwords(x))
                for i in range(len(docs)):
                    docs[i] = " ".join(docs[i]) 
                # Lemmatization
                for i in range(len(docs)):
                    doc = nlp(docs[i])
                    tokens = []
                    for token in doc:
                        tokens.append(token)
                    lemmatized_sentence = " ".join([token.lemma_ for token in doc])
                    docs[i] = lemmatized_sentence
                modal = BERTopic(language="english",n_gram_range=(1,3))
                try:
                    topics, probs = modal.fit_transform(docs)
                except:
                    print('Aspect contains only one phrase. BERTopic Error.\n')
                    continue
    
                df1['Cluster']=''
                df1.index=range(len(df1))
                predicted_topics, predicted_probs = modal.transform(docs)
                for i in range(len(df1)):
                    s = modal.get_topic(predicted_topics[i])[0][0]
                    l = s.split()
                    k = []
                    for x in l:
                        if (s.count(x)>=1 and (x not in k)):
                            k.append(x)
                    df1['Cluster'][i] = ' '.join(k)
#                 print(modal.get_topic_info())
                print(pd.DataFrame(df1['Cluster'].value_counts()))
                
                plt.figure(figsize=(25, 10))
                plt.xticks(rotation = 45)
                df1['Month'] = df1['Date'].str[3:]
                data = df1.drop(['Rating','index'],1).join(pd.get_dummies(df1['Cluster'])).groupby('Month').sum()
                data.reset_index(inplace=True)
                data['Month']=pd.to_datetime(data.Month)
                data.sort_values(['Month'],inplace=True)
                data['Month'] = data['Month'].apply(lambda x:x.strftime('%d_%b_%Y'))
                data['Month'] = data['Month'].str[3:]
                data.set_index(['Month'],inplace=True)
                sns.lineplot(data=data,markers=True, dashes=False,linewidth =2.3)
                sns.set_theme()
                plt.show()
                
                cluster_count = {}
                for review in df1.Review.unique():
                    for cluster in df1[df1.Review==review]['Cluster'].unique():
                        try:
                            cluster_count[cluster]+=1
                        except:
                            cluster_count[cluster]=1
                x = pd.DataFrame(df1.groupby('Cluster').count()['phrase'])
                x.columns = ['L3 Phrase Count']
                y = pd.DataFrame(cluster_count.values(),index=cluster_count.keys(),columns=['L3 Review Count'])
                z = pd.DataFrame(df1.groupby('Cluster').mean()['Rating'])
                z.columns = ['L3 Rating (Phrase)']
                a =pd.DataFrame(df1.groupby(['Cluster','Review']).mean().groupby('Cluster').mean()['Rating'])
                a.columns = ['L3 Rating (Review)']
                layer3 = x.join(y).join(z).join(a)
                layer3['Cluster'] = layer3.index
                layer3.index=range(len(layer3))
                
                s = sheet5[(sheet5['L2 Cluster']==aspect)]
                for i in s[s.Sentiment==senti].index:
                    try:
                        c = list(df1[df1.phrase==sheet5['L4 Phrases'][i]]['Cluster'])[0]
                        sheet5['L3 Cluster'][i] = list(layer3[layer3.Cluster==c]['Cluster'])[0]
                        sheet5['L3 Phrase Count'][i] = list(layer3[layer3.Cluster==c]['L3 Phrase Count'])[0]
                        sheet5['L3 Review Count'][i] = list(layer3[layer3.Cluster==c]['L3 Review Count'])[0]
                        sheet5['L3 Rating (Phrase)'][i] = list(layer3[layer3.Cluster==c]['L3 Rating (Phrase)'])[0]
                        sheet5['L3 Rating (Review)'][i] = list(layer3[layer3.Cluster==c]['L3 Rating (Review)'])[0]
                    except:
                        pass
            print("Clustering done after {:.2f} sec".format(time.time() - start_time))
    
    ###############################Layer2##############################################
    for senti in ['Positive','Negative']:
        a = sheet5[sheet5.Sentiment==senti]
        L2 = {}
        for aspect in a['L2 Cluster'].unique():
            b = a[a['L2 Cluster']==aspect]
            d = {}
            for cluster in b['L3 Cluster'].unique():
                c = b[b['L3 Cluster']==cluster]
                pcount = list(b[b['L3 Cluster']==cluster]['L3 Phrase Count'])[0]
                rcnt = list(b[b['L3 Cluster']==cluster]['L3 Review Count'])[0]
                prating = list(b[b['L3 Cluster']==cluster]['L3 Rating (Phrase)'])[0]
                rrat = list(b[b['L3 Cluster']==cluster]['L3 Rating (Review)'])[0]
                d[cluster] = [pcount,prating,rcnt,rrat]
            p_total = 0
            p_product = 0
            r_total = 0
            r_product = 0
            for key,value in d.items():
                try:
                    p_total+=value[0]
                    r_total+=value[2]
                except:
                    continue
                p_product+=(value[0]*value[1])
                r_product+=(value[2]*value[3])
            try:
                L2[aspect] = [p_total,p_product/p_total,r_total,r_product/r_total]
            except:
                continue
        for aspect,value in L2.items():
            for i in sheet5[(sheet5.Sentiment==senti) & (sheet5['L2 Cluster']==aspect)].index:
                sheet5['L2 Phrase Count'][i] = value[0]
                sheet5['L2 Rating (Phrase)'][i] = value[1]
                sheet5['L2 Review Count'][i] = value[2]
                sheet5['L2 Rating (Review)'][i] = value[3]
    print("Layer 2 Completed\n")
    
    #############################################Layer1#########################################
    d = {'Performance':['Allergy','Performance','Skin'],
         'Application':['Application','Texture'],
        'Emotional':['Brand','Competitor','Purchase','Sentiment'],
        'Product':['Demographic','Motivation','Odor','Packaging','Price']}
    for i in sheet5.index:
        l1 = ''
        for key,values in d.items():
            if sheet5['L2 Cluster'][i] in values:
                l1 = key
                break
        sheet5['L1 Cluster'][i] = key

    # sheet5['L1 Rating (Phrase)'] = sheet5['L1 Rating (Phrase)'].astype(float)
    # sheet5['L1 Rating (Review)'] = sheet5['L1 Rating (Review)'].astype(float)

    for senti in ['Positive','Negative']:
        a = sheet5[sheet5.Sentiment==senti]
        L2 = {}
        for aspect in a['L1 Cluster'].unique():
            b = a[a['L1 Cluster']==aspect]
            d = {}
            for cluster in b['L2 Cluster'].unique():
                c = b[b['L2 Cluster']==cluster]
                pcount = list(b[b['L2 Cluster']==cluster]['L2 Phrase Count'])[0]
                rcnt = list(b[b['L2 Cluster']==cluster]['L2 Review Count'])[0]
                prating = list(b[b['L2 Cluster']==cluster]['L2 Rating (Phrase)'])[0]
                rrat = list(b[b['L2 Cluster']==cluster]['L2 Rating (Review)'])[0]
                d[cluster] = [pcount,prating,rcnt,rrat]
            p_total = 0
            p_product = 0
            r_total = 0
            r_product = 0
    #         print(d)
            for key,value in d.items():
#                 print(senti,aspect,key,value)
                try:
                    p_total+=value[0]
                    r_total+=value[2]
                except:
                    continue
                p_product+=(value[0]*value[1])
                r_product+=(value[2]*value[3])
            try:
                L2[aspect] = [p_total,p_product/p_total,r_total,r_product/r_total]
            except:
                continue
        for aspect,value in L2.items():
            for i in sheet5[(sheet5.Sentiment==senti) & (sheet5['L1 Cluster']==aspect)].index:
                sheet5['L1 Phrase Count'][i] = value[0]
                sheet5['L1 Rating (Phrase)'][i] = value[1]
                sheet5['L1 Review Count'][i] = value[2]
                sheet5['L1 Rating (Review)'][i] = value[3]
    print("Layer 1 Completed\n")
    
    ###################################Id insertion & output excel formation################################
    id = 1
    for u_phrase in sheet5['L4 Phrases'].unique():
        for i in sheet5[sheet5['L4 Phrases']==u_phrase].index:
            sheet5['L4 ID'][i] = 'P4L4I'+ str(id)
        id+=1

    id = 1
    for u_cluster in sheet5['L3 Cluster'].unique():
        for i in sheet5[sheet5['L3 Cluster']==u_cluster].index:
            sheet5['L3 Cluster ID'][i] = 'P4L3I'+ str(id)
        id+=1

    id = 1
    for u_cluster in sheet5['L2 Cluster'].unique():
        for i in sheet5[sheet5['L2 Cluster']==u_cluster].index:
            sheet5['L2 Cluster ID'][i] = 'P4L2I'+ str(id)
        id+=1

    id = 1
    for u_cluster in sheet5['L1 Cluster'].unique():
        for i in sheet5[sheet5['L1 Cluster']==u_cluster].index:
            sheet5['L1 Cluster ID'][i] = 'P4L1I'+ str(id)
        id+=1

    d1 = sheet5
    d2 = sheet5.iloc[:,:19]
    d3 = sheet5.iloc[:,:13]
    d4 = sheet5.iloc[:,:7]
    
    d1 = d1.sort_values(['Sentiment'],ascending=False)
    d2 = d2.sort_values(['L3 Cluster','Sentiment'],ascending=False)
    d3 = d3.sort_values(['L2 Cluster','Sentiment'],ascending=False)
    d4 = d4.sort_values(['L1 Cluster','Sentiment'],ascending=False)
    
    d2.drop_duplicates(['Sentiment','L3 Cluster'],inplace=True)
    d3.drop_duplicates(['Sentiment','L2 Cluster'],inplace=True)
    d4.drop_duplicates(['Sentiment','L1 Cluster'],inplace=True)
    
#     d2.replace('',)
    d3.replace('',np.nan,inplace=True)
    d3.dropna(inplace=True)
    
    name = "detailed_op_"+cluster_algo+'_'+date+version+".xlsx"
    path = r"{fname}".format(fname=name)
    with pd.ExcelWriter(path) as engine:
        d1.to_excel(excel_writer=engine,sheet_name='L4',index=False)
        d2.to_excel(excel_writer=engine,sheet_name='L3',index=False)
        d3.to_excel(excel_writer=engine,sheet_name='L2',index=False)
        d4.to_excel(excel_writer=engine,sheet_name='L1',index=False)
    print("Excel File with 4 sheets is created.\n")
    dfs = [d1,d2,d3,d4]
    return dfs

# %% [markdown]
# # df -> Docano Output

# %%
def getIndex(text, phrase):
    text, phrase = text.lower(), phrase.lower()
    text, phrase = text.strip(), phrase.strip()
    
    if text.find(phrase) != -1:
        return text.find(phrase)
    
    lastWord = phrase.split()[-1]
    lastWordIndex = text.find(lastWord)
    
    if lastWordIndex != -1:
        return lastWordIndex - (len(phrase) - len(lastWord))
    
    firstWord = phrase.split()[0]
    firstWordIndex = text.find(firstWord)
    
    if firstWordIndex != -1:
        return firstWordIndex
    
    return -1

df3["startIndex"] = df3.apply(lambda x : getIndex(x["Review"], x["phrase"]), axis = 1)

df3 = df3[df3.startIndex != -1]
df3['endIndex'] = df3['startIndex']+len(df3['phrase'])

df3['sentiment'] = df3['sentiment'].str.replace('Positive','pos')
df3['sentiment'] = df3['sentiment'].str.replace('Negative','neg')
        
df3['id'] = df3['Review ID'].str.split('P4R',expand=True).iloc[:,[1]]
df3['Tag'] = df3['sentiment']+'_'+df3['aspect']
df3.rename(columns={'Review':'text'},inplace=True)
df3['id'] = df3['id'].astype(int)
df3.sort_values(['id','startIndex'],inplace=True)

df3['entity'] = ''
for i in df3.index:
    l = []
    l.append(int(df3['startIndex'][i]))
    l.append(int(df3['endIndex'][i]))
    l.append(df3['Tag'][i])
    df3['entity'][i] = l
    
# df3.drop(['Review ID','sentiment','aspect','Tag','startIndex','endIndex','Phrase'],1,inplace=True)

keyList = ["id", "text", "Date","Rating","cats","entities","Comments"]

dl = []
for id in df3['id'].unique():
    d = {}
    for i in keyList:
        d[i] = None
    d['id'] = int(id)
    d['text'] = list(df3[df3['id']==id]['text'])[0]
    d['Date'] = list(df3[df3['id']==id]['Date'])[0]
    d['Rating'] = list(df3[df3['id']==id]['Rating'])[0]
    d['cats'] = []
    d['entities'] = list(df3[df3['id']==id]['entity'])
    d['Comments'] = []
    dl.append(d)

with open("doccano_op_20221226v1.jsonl", 'w', encoding="utf8") as f:
    for item in dl:
        f.write(json.dumps(item) + "\n")
